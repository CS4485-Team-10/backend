# %% [markdown]
# # **YouTube Data Ingestion Pipeline**
#
# This notebook accomplishes the following:
# 1. Pull official YouTube metadata via Google's YouTube Data API
# 2. Pull transcripts via an external API, provided a video ID

# %% [markdown]
# ## Import Libraries and Environment Variables

# %%
import os
import re
import shutil
from pathlib import Path
from dotenv import load_dotenv
from googleapiclient.discovery import build
from typing import Union, List, Dict
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter

# Resolve to backend/data (notebook runs from backend/pipelines/ so cwd is pipelines)
DATA_ROOT = (
    Path.cwd().parent / "data"
    if Path.cwd().name == "pipelines"
    else Path.cwd() / "data"
)


def clear_data_dirs():
    """Clear subdirectories: metadata, transcripts/cleaned, transcripts/raw, comments."""
    dirs = [
        DATA_ROOT / "metadata",
        DATA_ROOT / "transcripts" / "cleaned",
        DATA_ROOT / "transcripts" / "raw",
        DATA_ROOT / "comments",
    ]
    for d in dirs:
        if d.exists():
            shutil.rmtree(d)
        d.mkdir(parents=True, exist_ok=True)


# Initialize by cleaning data directories using function above...
clear_data_dirs()

# %%
# Load .env file
load_dotenv()
YT_API_KEY = os.getenv("YOUTUBE_DATA_API_KEY")

# %% [markdown]
# ## Stage 1: Query Video IDs from YouTube Data API

# %%
"""
- Build a service object with appropriate credentials to pull data from YouTube, with the following constraints:
    - Ordering query results by view count (greatest to least)
    - Time frame limited to last 6 months
"""

youtube = build(serviceName="youtube", version="v3", developerKey=YT_API_KEY)

# %%
from datetime import datetime, timedelta, timezone

six_months_ago = (datetime.now(timezone.utc) - timedelta(days=180)).strftime(
    "%Y-%m-%dT00:00:00Z"
)

# Paginated search: fetch multiple pages (50 video requests per page)
MAX_SEARCH_PAGES = 10
all_items = []
page_token = None

for _ in range(MAX_SEARCH_PAGES):
    resp = (
        youtube.search()
        .list(
            q="personal health",
            part="snippet",
            type="video",
            maxResults=50,
            publishedAfter=six_months_ago,
            order="viewCount",
            pageToken=page_token,
        )
        .execute()
    )
    all_items.extend(resp.get("items", []))
    page_token = resp.get("nextPageToken")
    if not page_token:
        break

# response structure compatible with downstream (response["items"])
response = {"items": all_items}

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# - Previewing nested dictionary structure & relevant attributes for feature selection
#     -  `response["items]`: list of search results (each formatted as a dict)
#
#
#
#
#
# - Response attributes which aren't useful beyond validation:
#     - `'kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo'`

# %%
# if it's a plain dict-like thing
print(f"Dictionary Structure:\n{response.keys()}")

from pprint import pprint

print("\nFull Response Dictionary Structure:\n")
pprint(response)
# Out:
# Dictionary Structure:
# dict_keys(['items'])
#
# Full Response Dictionary Structure:
#
# {'items': [{'etag': 'TDsa5I54kTcTy8WgQ9VRlSYr5k8',
#             'id': {'kind': 'youtube#video', 'videoId': '0fb7SsSIlqM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCwAdQUuPT6laN-AQR17fe1g',
#                         'channelTitle': 'Pranjal Kamra',
#                         'description': 'Compare Best Health Plans with Ditto: '
#                                        'https://ditto.sh/6zwj4x After the GST '
#                                        'reforms, many of you asked us to bring '
#                                        'back our annual ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-28T13:24:43Z',
#                         'publishedAt': '2025-10-28T13:24:43Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Best Health Insurance Plans 2026'}},
#            {'etag': 'wISvp419_qUqtef6SrkQA1-iiDo',
#             'id': {'kind': 'youtube#video', 'videoId': 'MZ65Z8papwg'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCuYHZz4-qdDSPNvuCfN4wMQ',
#                         'channelTitle': 'The New Culture Forum',
#                         'description': 'SUBSCRIBE: If you are enjoying the '
#                                        'show, please subscribe to our channel '
#                                        'on YouTube (click the Subscribe Button '
#                                        'underneath ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-14T17:00:37Z',
#                         'publishedAt': '2025-10-14T17:00:37Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/MZ65Z8papwg/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/MZ65Z8papwg/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/MZ65Z8papwg/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'A Personal Health Statement from Peter '
#                                  'Whittle, Founder &amp; Director of the New '
#                                  'Culture Forum '}},
#            {'etag': '4p-4m84QzRzrfQkaLUAYhpXoL5o',
#             'id': {'kind': 'youtube#video', 'videoId': '9Zz6Nj0xwXM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCH1oRy1dINbMVp3UFWrKP0w',
#                         'channelTitle': 'Good Morning America',
#                         'description': 'The former "GMA" chief medical editor, '
#                                        'who held the role for more than three '
#                                        'decades, joins the show to discuss his '
#                                        'own battle ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-17T17:10:00Z',
#                         'publishedAt': '2025-12-17T17:10:00Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/9Zz6Nj0xwXM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/9Zz6Nj0xwXM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/9Zz6Nj0xwXM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Dr. Tim Johnson details personal health '
#                                  'battle'}},
#            {'etag': 'xI-8zu4amMSJisMX0Gq9T7twuPA',
#             'id': {'kind': 'youtube#video', 'videoId': 'gpzDxm7qflY'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC2A6IJQ6AZaK_f_r24his6g',
#                         'channelTitle': 'Dr Sermed Mezher',
#                         'description': 'Sources- PMID 30766283 sevilikes on TT '
#                                        'The term "almond husband" describes a '
#                                        'partner whose commitment to a healthy '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-27T20:07:54Z',
#                         'publishedAt': '2026-02-27T20:07:54Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/gpzDxm7qflY/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/gpzDxm7qflY/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/gpzDxm7qflY/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Got an Almond Husband? Doctor Explains'}},
#            {'etag': 'RZNFf7sRcd0q1WSxmRbQYQVltBY',
#             'id': {'kind': 'youtube#video', 'videoId': 'kRLWY-u52jU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCXW8HfQr4dI1FMVHHmsEwyw',
#                         'channelTitle': 'LIVE4WELL',
#                         'description': 'AI-Driven Preventive Healthcare Launch '
#                                        'Event” wrapped up successfully one '
#                                        "week ago! We're deeply grateful for "
#                                        'the positive ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-03T12:11:45Z',
#                         'publishedAt': '2025-11-03T12:11:45Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Event Recap：AI-Driven Preventive Healthcare '
#                                  'Launch Event - Your Personal Health Butler '
#                                  'Is Now Online'}},
#            {'etag': 'RQNdfa8eHbVMW5OcdW5rrqn89Kc',
#             'id': {'kind': 'youtube#video', 'videoId': 'pP0cCa7CbQo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCv_iDwcZUJH66i_QWpT_mqQ',
#                         'channelTitle': 'The Carpetbagger',
#                         'description': 'Intro by Cre80s '
#                                        'https://linktr.ee/cre80s If you would '
#                                        'like to make a contribution, my '
#                                        'Patreon can be found here ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-17T15:09:31Z',
#                         'publishedAt': '2026-02-17T15:09:31Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Doctor&#39;s Appointment - My Personal '
#                                  'Health - Future Plans - Big Trip Coming'}},
#            {'etag': 'GX2kyb1-nkSry1Bx-LNCplXVYOA',
#             'id': {'kind': 'youtube#video', 'videoId': 'FBNHixjtR_o'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCWr_Tc_p0r--cXDWdU1wI2Q',
#                         'channelTitle': 'Fame Scope',
#                         'description': 'These four celebrities faced '
#                                        'life-changing health battles that '
#                                        'permanently altered their daily lives. '
#                                        'From serious medical ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-26T09:10:38Z',
#                         'publishedAt': '2026-02-26T09:10:38Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/FBNHixjtR_o/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/FBNHixjtR_o/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/FBNHixjtR_o/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '4 Celebrities Who Can&#39;t Live a Normal '
#                                  'Life - Heartbreaking Stories'}},
#            {'etag': 'nn7IvToBUwrDiJc41an4WMeFXtM',
#             'id': {'kind': 'youtube#video', 'videoId': '-5d7CLE7-8U'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCSUi3x8uJ_zuy-arn2eDYVw',
#                         'channelTitle': 'Elen’s life USA',
#                         'description': 'This video/content was created with '
#                                        'the assistance of AI technology. '
#                                        'Disclaimer: All content and media on '
#                                        'this channel are for ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-07T04:22:08Z',
#                         'publishedAt': '2025-12-07T04:22:08Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/-5d7CLE7-8U/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/-5d7CLE7-8U/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/-5d7CLE7-8U/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'IՃիշտ մթերքներ արյան ճնշումը իջեցնելուն '
#                                  '#doctor #armeniatv #nurse #Blood pressure '
#                                  '#facts'}},
#            {'etag': 'UjPJF3ef-o_DpxDrz6pn6gpejYQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'dcqCCTLC3uo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC8WrThxRtrfupVw3iYow9ag',
#                         'channelTitle': 'Novelitedits',
#                         'description': 'Take care of yourself Shiori! '
#                                        '------------------------------------------------------------------------------------ '
#                                        'Watch the full VOD here! The Slow ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-20T11:30:24Z',
#                         'publishedAt': '2025-10-20T11:30:24Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Shiori Shares a Personal Health '
#                                  'Update【Hololive EN】'}},
#            {'etag': 'JDI6mSlmYEqBRa7gUkK5J7DEvpE',
#             'id': {'kind': 'youtube#video', 'videoId': 'BIaBB4nc80s'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCwtXc_jRGeVE5KEBnnUyleg',
#                         'channelTitle': 'AKY ZONE 2.0',
#                         'description': 'VitalWear SmartBand – The Next-Gen '
#                                        "Fitness Tracker You've Been Waiting "
#                                        'For! Say hello to the future of '
#                                        'wearable ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-03-04T16:03:35Z',
#                         'publishedAt': '2026-03-04T16:03:35Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/BIaBB4nc80s/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/BIaBB4nc80s/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/BIaBB4nc80s/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '🔥 VitalWear SmartBand – The Next-Gen Fitness '
#                                  'Tracker You’ve Been Waiting For! 💪📱'}},
#            {'etag': 'zUVati6rxfKS9PeIwYZaDD1KeDE',
#             'id': {'kind': 'youtube#video', 'videoId': 'e_wUjrlISrg'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC6Xt29Fi1ES6C1fEtWFUFIw',
#                         'channelTitle': 'Purple FTW! Podcast',
#                         'description': 'Minnesota Vikings safety Harrison '
#                                        'Smith Feeds the Local Media Jackals, '
#                                        'Talks Personal Health Issue. DONATION '
#                                        'LINKS Venmo: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-09-10T20:33:30Z',
#                         'publishedAt': '2025-09-10T20:33:30Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Harrison Smith Feeds the Local Media '
#                                  'Jackals, Talks Personal Health Issue'}},
#            {'etag': 'fOsCM4BXMwyUUoQE0yOwKN9Gd58',
#             'id': {'kind': 'youtube#video', 'videoId': 'erbL4NYxu3M'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCaJaf-9hoEsIyNonnUmOnSA',
#                         'channelTitle': '🥇 GrevoFX',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-08T06:45:04Z',
#                         'publishedAt': '2025-11-08T06:45:04Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/erbL4NYxu3M/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/erbL4NYxu3M/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/erbL4NYxu3M/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'VitaWear SmartBand 😆Your Personal  Health '
#                                  'Partner #ytshorts #shortvideos #viral '
#                                  '#shortsfeed'}},
#            {'etag': 'TF_GfBED_ulke0NXdJL3MbL-WmQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'iltSi4jfUAU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCbn_UgG0hhLvSwfcYEqIruw',
#                         'channelTitle': 'MH news',
#                         'description': "lBeyond Business: Ratan Tata's "
#                                        'Personal Health Battle & His Support '
#                                        'System" #shorts #trending #news.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-07T09:52:16Z',
#                         'publishedAt': '2026-01-07T09:52:16Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/iltSi4jfUAU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/iltSi4jfUAU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/iltSi4jfUAU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'lBeyond Business: Ratan Tata&#39;s Personal '
#                                  'Health Battle &amp; His Support System&quot; '
#                                  '#shorts #trending #news'}},
#            {'etag': 'Hj0S--AVtY5VHFoUTl1dgrfh4zI',
#             'id': {'kind': 'youtube#video', 'videoId': 'o8ckn8OolY8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC2u36t2NO8nRTn-5s21kLMg',
#                         'channelTitle': 'FemHealth: For You From Doctors',
#                         'description': 'Pelvic Floor Surgeon & Board Certified '
#                                        'Urologist Doctor Rena Malik explains '
#                                        'the 6 most common reasons for hymen '
#                                        'breakage.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-03-01T23:43:00Z',
#                         'publishedAt': '2026-03-01T23:43:00Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/o8ckn8OolY8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/o8ckn8OolY8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/o8ckn8OolY8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Doctor Explains Medical Hymen Definition | '
#                                  'Anatomic Hymen Breakage Causes'}},
#            {'etag': 'uML0sSl2xW62VN4c6Igci4ZTFqw',
#             'id': {'kind': 'youtube#video', 'videoId': '0QTtczsrCc0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCyUsjAve-53uO-4npQr5vDA',
#                         'channelTitle': 'VOOTKURI VLOGS',
#                         'description': 'This video is created using Artificial '
#                                        'Intelligence (AI) for educational '
#                                        'purposes and easy understanding. In '
#                                        'this video, we explained ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-27T12:30:38Z',
#                         'publishedAt': '2026-02-27T12:30:38Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/0QTtczsrCc0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/0QTtczsrCc0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/0QTtczsrCc0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'మీరు కూడా వారానికి రెండు సార్లు తినండి '
#                                  '#trending #kakarkaya #tips #health '
#                                  '#shortsfeed #viral'}},
#            {'etag': 'NzXLvBSClcZ4Wg1etXb-767ymW8',
#             'id': {'kind': 'youtube#video', 'videoId': 'TZ7LBBngViQ'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCey_c7U86mJGz1VJWH5CYPA',
#                         'channelTitle': 'iJustine',
#                         'description': "I've teamed up with @withings to "
#                                        'showcase the future of personal health '
#                                        'tech! Head to the link in my bio to '
#                                        'learn more #ad ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-02T21:53:18Z',
#                         'publishedAt': '2025-12-02T21:53:18Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/TZ7LBBngViQ/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/TZ7LBBngViQ/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/TZ7LBBngViQ/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Future of Personal Health Tech!'}},
#            {'etag': 'bdZJPC2CGZW4StZwY5YNRVnsksk',
#             'id': {'kind': 'youtube#video', 'videoId': 'UbwaJQLdeLk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCvixJtaXuNdMPUGdOPcY8Ag',
#                         'channelTitle': 'David Pakman Show',
#                         'description': 'trump #trumphealth.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-06T13:00:54Z',
#                         'publishedAt': '2025-10-06T13:00:54Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'BIZARRE: Trump brags about his personal '
#                                  'health in speech intended to celebrate the '
#                                  'Navy #shorts'}},
#            {'etag': 'qfbkWiXFHC5Jzj2vexFzEm4mrF0',
#             'id': {'kind': 'youtube#video', 'videoId': '84Q-6Wox9bU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCGPhc1kNLRZBClfuOcuVqIw',
#                         'channelTitle': 'Buzz snap',
#                         'description': "Award-winning actress Lupita Nyong'o "
#                                        'recently shared a heartfelt update '
#                                        'about her personal health journey '
#                                        'during an ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-28T01:00:10Z',
#                         'publishedAt': '2026-02-28T01:00:10Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/84Q-6Wox9bU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/84Q-6Wox9bU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/84Q-6Wox9bU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Lupita Nyong’o Opens Up About Her Health '
#                                  'Journey 💛 | Inspiring &amp; Honest Interview '
#                                  '#shorts'}},
#            {'etag': 'ghiNpdMe4BeDC4QMO9vmP1yqfIw',
#             'id': {'kind': 'youtube#video', 'videoId': 'XI0vDlgCZbU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCUykE2XJkEd2IfMh3NQFKVg',
#                         'channelTitle': 'Hatching For Health',
#                         'description': 'After a life-changing injury, the path '
#                                        'to healing can be long—but it can also '
#                                        'reveal incredible strength. In this '
#                                        'inspiring episode ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-08T20:00:34Z',
#                         'publishedAt': '2025-11-08T20:00:34Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Road to Recovery: Overcoming Personal '
#                                  'Injury | Hatching for Health Episode 10'}},
#            {'etag': 'vxghuilm9u-QcX3mn_qT-tSO1qA',
#             'id': {'kind': 'youtube#video', 'videoId': 'sfsd8GdM9mk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC20D718p_EzFY0kSRONA99Q',
#                         'channelTitle': 'Consciouz Tv',
#                         'description': 'Ctv #Consciouztv #StormMonroe '
#                                        '#Unwinewithtashak #KattWilliams '
#                                        '#Trending #CelebrityNews *Cash app: '
#                                        '$Consciouztv ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-13T04:49:37Z',
#                         'publishedAt': '2025-10-13T04:49:37Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/sfsd8GdM9mk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/sfsd8GdM9mk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/sfsd8GdM9mk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Storm Monroe TALKS Africa, Lap Dogs, HIV, '
#                                  'Personal Health, Powda Head Stalkers &amp; '
#                                  'Tasha K Regrets?'}},
#            {'etag': 'aet8RKSpQWWTiiHILWH7R2pchN8',
#             'id': {'kind': 'youtube#video', 'videoId': 'bvOxqF1GTcc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCnQgtMjFK-zcsc5TTv-IO4g',
#                         'channelTitle': 'Daily Life Health',
#                         'description': 'What happens inside your kidneys after '
#                                        'drinking soda vs water? Sugary soda '
#                                        'can increase blood sugar levels and '
#                                        'force your ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-03-03T13:30:44Z',
#                         'publishedAt': '2026-03-03T13:30:44Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/bvOxqF1GTcc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/bvOxqF1GTcc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/bvOxqF1GTcc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Soda vs Water: What Happens Inside Your '
#                                  'Kidneys? 🥤💧'}},
#            {'etag': 'h9bKEBQPh-UhC1nkz6Jo1JALZ1M',
#             'id': {'kind': 'youtube#video', 'videoId': 'MoBqiwSkEDs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCXW8HfQr4dI1FMVHHmsEwyw',
#                         'channelTitle': 'LIVE4WELL',
#                         'description': 'A heartfelt thank you to all our guest '
#                                        'of honor & morning session speakers '
#                                        'for attending and supporting '
#                                        '“AI-Driven Preventive ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-31T17:01:49Z',
#                         'publishedAt': '2025-10-31T17:01:49Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/MoBqiwSkEDs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/MoBqiwSkEDs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/MoBqiwSkEDs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AI-Driven Preventive Healthcare Launch Event '
#                                  '- Your Personal Health Butler Is Now Online '
#                                  '| LIVE4WELL'}},
#            {'etag': 'Ln1BrM-T9A-rUemg_1hP_6za2bs',
#             'id': {'kind': 'youtube#video', 'videoId': 'Mlww9rzn1XM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZEOvoFUl6pkx7rts8KKkhw',
#                         'channelTitle': 'Boxing Social',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-02T14:46:50Z',
#                         'publishedAt': '2025-12-02T14:46:50Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Chris Eubank Jr provides an update on his '
#                                  'personal health battles on social media. 🙏'}},
#            {'etag': 'ZYCanFbell25sxE2BzI04SNZ4JA',
#             'id': {'kind': 'youtube#video', 'videoId': '2KZXPHGhnuE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCqzK60-oUOEq36uU9B1MMUg',
#                         'channelTitle': 'Julia McCoy',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-03T16:30:39Z',
#                         'publishedAt': '2025-10-03T16:30:39Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/2KZXPHGhnuE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/2KZXPHGhnuE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/2KZXPHGhnuE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Major personal health update | healing isn’t '
#                                  'linear ❤️\u200d🩹'}},
#            {'etag': 'mCYq_HBrqeWCURzbSn3GT5u6j8Y',
#             'id': {'kind': 'youtube#video', 'videoId': 'xHSqr7jAciM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCBa5G_ESCn8Yd4vw5U-gIcg',
#                         'channelTitle': 'Stanford Online',
#                         'description': "Learn more about Stanford's Healthcare "
#                                        'AI programs: '
#                                        'https://stanford.io/3ETLFCx Check out '
#                                        'the AI in Healthcare series playlist: '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-25T21:43:07Z',
#                         'publishedAt': '2025-11-25T21:43:07Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AI in Healthcare Series: AI as Your Personal '
#                                  'Health Partner'}},
#            {'etag': 'C4gvmgH1-8EBILhwZJIox735UQ0',
#             'id': {'kind': 'youtube#video', 'videoId': '7zarPsHgK_c'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC3VK7N6Ap360P6RvClj9wdQ',
#                         'channelTitle': 'Mlbb only',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-13T06:00:06Z',
#                         'publishedAt': '2025-11-13T06:00:06Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/7zarPsHgK_c/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/7zarPsHgK_c/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/7zarPsHgK_c/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Full kesehatan pribadi'}},
#            {'etag': 'uF1dx17Gkea68Vr_kxBN4i6J3B8',
#             'id': {'kind': 'youtube#video', 'videoId': 'w5cts1BYI3o'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC8CxefpmMRp2F82bAWAMuhg',
#                         'channelTitle': 'MaxTalksTech',
#                         'description': 'Free personal health companion. Ask '
#                                        'any health question, review your labs, '
#                                        'optimize your health protocol, review '
#                                        'your insurance ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-21T15:12:51Z',
#                         'publishedAt': '2026-02-21T15:12:51Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Free personal health companion. Ask any '
#                                  'health question, review your labs, optimize '
#                                  'your health'}},
#            {'etag': 'KOpzt80llGFW0uOL5H21aKnPGHU',
#             'id': {'kind': 'youtube#video', 'videoId': 'tjujcQXt4q0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCkoQ_GRNWhWiKYNDGfOPQPA',
#                         'channelTitle': 'KING MOTIV8',
#                         'description': "Tori didn't just transform her body. "
#                                        'She rebuilt her life. Starting at 434 '
#                                        'lbs, emotional eating and survival '
#                                        'habits felt impossible to ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-26T10:20:00Z',
#                         'publishedAt': '2026-02-26T10:20:00Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/tjujcQXt4q0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/tjujcQXt4q0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/tjujcQXt4q0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '217lbs Down. 2 Surgeries Later. Still '
#                                  'Standing Strong 👑 | QUEEN MACHINE'}},
#            {'etag': 'qQD_KUlKwYS3UdmnndL37svGb_Q',
#             'id': {'kind': 'youtube#video', 'videoId': 'oKzwh4sB3P8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCTiQM-IsGr9WggtXVJk1EKg',
#                         'channelTitle': 'Ayuda Health',
#                         'description': 'Experience a smarter way to manage '
#                                        'your #health with Ayuda Health — your '
#                                        'AI-powered personal health assistant. '
#                                        'Whether ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-04T18:49:41Z',
#                         'publishedAt': '2025-11-04T18:49:41Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AI-Powered Personal Health Support | Ayuda '
#                                  'Health'}},
#            {'etag': 'c-XoglXP855CaA2AlWMX_xWjTQk',
#             'id': {'kind': 'youtube#video', 'videoId': '57ZtFv3Q4Qo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC4tFwx7EBwI9z9hr0F1cD_w',
#                         'channelTitle': 'Sức Sống 360',
#                         'description': 'Điều gì xảy ra khi bạn không ăn bất cứ '
#                                        'thứ gì trong 24 giờ? Tập 1 - #Shorts - '
#                                        'Bí quyết sống khỏe cùng Sức Sống 360 ✓ '
#                                        'Đăng ký ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-27T09:52:18Z',
#                         'publishedAt': '2026-02-27T09:52:18Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/57ZtFv3Q4Qo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/57ZtFv3Q4Qo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/57ZtFv3Q4Qo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Điều gì xảy ra khi bạn không ăn bất cứ thứ '
#                                  'gì trong 24 giờ? Tập 1 - #Shorts'}},
#            {'etag': '6-SdDUKrSiNSMOc9RZ3G1bPu4mo',
#             'id': {'kind': 'youtube#video', 'videoId': 'uPnXnPFEnho'},
#             'kind': 'youtube#searchResult',
# ...
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCXM4rMP_2fWvjcVP4UH0G1Q',
#                         'channelTitle': 'DATC Media Company',
#                         'description': 'This week on the show, Sara J. is '
#                                        'sharing a bit of personal news and a '
#                                        'health update. Support: '
#                                        'https://gofund.me/87d861182 ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-25T00:06:34Z',
#                         'publishedAt': '2026-02-25T00:06:34Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/N3lA2o_7GNM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/N3lA2o_7GNM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/N3lA2o_7GNM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Personal News  &amp; Health Update'}},
#            {'etag': '_HcuT_u-ezSMXS_8bTj4jp0Sp58',
#             'id': {'kind': 'youtube#video', 'videoId': 'rWuBfNH87AA'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCASR7nz9vIDOShxdeUplrxg',
#                         'channelTitle': 'Orlando Health',
#                         'description': 'Join host Elizabeth Hart, Dr. Michael '
#                                        'V. Jablonski and Dr. George J. '
#                                        'Haidukewych and learn how Orlando '
#                                        'Health Jewett ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-26T20:09:52Z',
#                         'publishedAt': '2026-02-26T20:09:52Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/rWuBfNH87AA/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/rWuBfNH87AA/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/rWuBfNH87AA/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'We Make It Personal - Orlando Health Jewett '
#                                  'Orthopedic Institute Celebrates 1-Year '
#                                  'Anniversary'}},
#            {'etag': 'j2MtHdZQTPkZ1tnLxaut_Qypg4I',
#             'id': {'kind': 'youtube#video', 'videoId': 'VPC1LU24f3s'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZvJTxllbx-FG_9yYN1PS4w',
#                         'channelTitle': 'Viriyah Health Insurance - '
#                                         'วิริยะประกันสุขภาพ',
#                         'description': 'ที่มาพร้อมกับคำแนะนำของคุณหมอ '
#                                        'เจาะลึกสุขภาพจากภายใน '
#                                        'ด้วยข้อมูลเฉพาะบุคคล โดย นายแพทย์ '
#                                        'จตุพล สุวรรณพินิจ ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T04:41:23Z',
#                         'publishedAt': '2026-02-23T04:41:23Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/VPC1LU24f3s/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/VPC1LU24f3s/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/VPC1LU24f3s/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '\u200b\u200bHealthy life By Viriyah Health '
#                                  'Advisory EP.43 &quot;Personal check-up '
#                                  'เจาะลึกการตรวจสุขภาพอย่างตรงจุด&quot;'}},
#            {'etag': 'Gq6DuCjSPpzlkztdRIsu7wmS6HQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'WdIMw38d9cg'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCWirsSiG6zAuZJbz4NUqWWw',
#                         'channelTitle': 'Endeavor Health',
#                         'description': 'Healthcare leadership at Endeavor '
#                                        'Health is focused on creating safe, '
#                                        'seamless and personal care for every '
#                                        'patient.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-27T16:45:53Z',
#                         'publishedAt': '2026-02-27T16:45:53Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/WdIMw38d9cg/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/WdIMw38d9cg/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/WdIMw38d9cg/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Healthcare leadership at Endeavor Health: '
#                                  'Katie McGovern on safe, seamless and '
#                                  'personal care'}},
#            {'etag': 'AIMgQac8FPrusRUMnSlBNC3K1NY',
#             'id': {'kind': 'youtube#video', 'videoId': 'ZIzd6G-FNC8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCscFBLbnrdUBaDVQWgn0MqQ',
#                         'channelTitle': 'Trending Mania',
#                         'description': 'Bruce Campbell Shares Emotional Health '
#                                        'Update Actor Bruce Campbell has shared '
#                                        'a personal health update with fans. '
#                                        'The Evil ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-03-03T23:00:45Z',
#                         'publishedAt': '2026-03-03T23:00:45Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/ZIzd6G-FNC8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/ZIzd6G-FNC8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/ZIzd6G-FNC8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Bruce Campbell Shares Emotional Health '
#                                  'Update'}},
#            {'etag': 'td_AU_jvpQ1CJYhGNmTU-xVyuCA',
#             'id': {'kind': 'youtube#video', 'videoId': 'fH3RWSLYJeo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCyQ1cM2h4Bi2FB87WRVnl_Q',
#                         'channelTitle': 'raj chaitanya',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-19T12:48:04Z',
#                         'publishedAt': '2026-02-19T12:48:04Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/fH3RWSLYJeo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/fH3RWSLYJeo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/fH3RWSLYJeo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'V5.0 favors node health, not luck! 🔥Personal '
#                                  'node health #InterLink #ITLG #ITL'}},
#            {'etag': 'kS0V58NytZzMCgOpk8wLpIX9v3Q',
#             'id': {'kind': 'youtube#video', 'videoId': 'lrMZ4OjVR-o'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCzcunT4izof8P3XjmbRd5IQ',
#                         'channelTitle': 'WIBW 13 NEWS | Topeka, KS',
#                         'description': 'WIBW #Kansas #13news For more Local '
#                                        'News from WIBW: https://www.wibw.com/ '
#                                        'For more YouTube Content: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T22:35:13Z',
#                         'publishedAt': '2026-02-23T22:35:13Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/lrMZ4OjVR-o/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/lrMZ4OjVR-o/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/lrMZ4OjVR-o/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Local farmer, rancher shares personal '
#                                  'connection to promote awareness for mental '
#                                  'health in the ag...'}},
#            {'etag': 'S_FZGNsQJMJwb-YlT5Znf4m73iY',
#             'id': {'kind': 'youtube#video', 'videoId': 'XKmZ83WcSTE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC3Z1MzQ1h1q226QMnTNJv8A',
#                         'channelTitle': 'Dirmedal',
#                         'description': 'Ante la ola de violencia en #Jalisco '
#                                        'algunos trabajadores de la salud no '
#                                        'podían asistir a su trabajo en '
#                                        '#hospitales y de no ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-03-05T00:00:37Z',
#                         'publishedAt': '2026-03-05T00:00:37Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/XKmZ83WcSTE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/XKmZ83WcSTE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/XKmZ83WcSTE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Piden al  personal de salud que demuestre '
#                                  'por qué faltó durante jornada de violencia '
#                                  'en Jalisco'}},
#            {'etag': '2jbG7mMbM6_CiyXda3pFtbh8Ji4',
#             'id': {'kind': 'youtube#video', 'videoId': 'KL7DQQJkdO0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCmdxRoVi2Jt8FsBuAcVnocA',
#                         'channelTitle': 'Infiuss Health',
#                         'description': 'What if you could test a health '
#                                        'decision before making it? | Digital '
#                                        'Patient Twin | Infiuss HealthMeet '
#                                        'Melissa. Her doctor just ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T00:33:26Z',
#                         'publishedAt': '2026-02-23T00:33:26Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/KL7DQQJkdO0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/KL7DQQJkdO0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/KL7DQQJkdO0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Introducing Infiuss Health&#39;s Digital '
#                                  'patient twins for personal health '
#                                  'optimisation'}},
#            {'etag': 'HT2AKWMWH3w9lLMfgeEJz_ej1Sk',
#             'id': {'kind': 'youtube#video', 'videoId': '_sfriPaSNaU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCi23soTUZ6Wag5vs-t6sCCg',
#                         'channelTitle': 'Dr. Moumita Health Guide  ',
#                         'description': 'ব্যক্তিগত স্বাস্থ্য অবহেলা করলে ধীরে '
#                                        'ধীরে শরীরে নানা সমস্যা তৈরি ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T05:22:51Z',
#                         'publishedAt': '2026-02-23T05:22:51Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/_sfriPaSNaU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/_sfriPaSNaU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/_sfriPaSNaU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Personal Health Neglect করলে শরীরে কী হয়? '
#                                  'চমকে উঠবেন!'}}]}

# %%
# For each search result:
for item in response["items"]:
    # Print the video's title & channel title
    print(item["snippet"]["title"])
    print(item["snippet"]["channelTitle"])
    print("------------")
# Out:
# Best Health Insurance Plans 2026
# Pranjal Kamra
# ------------
# A Personal Health Statement from Peter Whittle, Founder &amp; Director of the New Culture Forum
# The New Culture Forum
# ------------
# Dr. Tim Johnson details personal health battle
# Good Morning America
# ------------
# Got an Almond Husband? Doctor Explains
# Dr Sermed Mezher
# ------------
# Event Recap：AI-Driven Preventive Healthcare Launch Event - Your Personal Health Butler Is Now Online
# LIVE4WELL
# ------------
# Doctor&#39;s Appointment - My Personal Health - Future Plans - Big Trip Coming
# The Carpetbagger
# ------------
# 4 Celebrities Who Can&#39;t Live a Normal Life - Heartbreaking Stories
# Fame Scope
# ------------
# IՃիշտ մթերքներ արյան ճնշումը իջեցնելուն #doctor #armeniatv #nurse #Blood pressure #facts
# Elen’s life USA
# ------------
# Shiori Shares a Personal Health Update【Hololive EN】
# Novelitedits
# ------------
# 🔥 VitalWear SmartBand – The Next-Gen Fitness Tracker You’ve Been Waiting For! 💪📱
# AKY ZONE 2.0
# ------------
# Harrison Smith Feeds the Local Media Jackals, Talks Personal Health Issue
# Purple FTW! Podcast
# ------------
# VitaWear SmartBand 😆Your Personal  Health Partner #ytshorts #shortvideos #viral #shortsfeed
# 🥇 GrevoFX
# ------------
# lBeyond Business: Ratan Tata&#39;s Personal Health Battle &amp; His Support System&quot; #shorts #trending #news
# MH news
# ------------
# Doctor Explains Medical Hymen Definition | Anatomic Hymen Breakage Causes
# FemHealth: For You From Doctors
# ------------
# మీరు కూడా వారానికి రెండు సార్లు తినండి #trending #kakarkaya #tips #health #shortsfeed #viral
# VOOTKURI VLOGS
# ------------
# The Future of Personal Health Tech!
# iJustine
# ------------
# BIZARRE: Trump brags about his personal health in speech intended to celebrate the Navy #shorts
# David Pakman Show
# ------------
# Lupita Nyong’o Opens Up About Her Health Journey 💛 | Inspiring &amp; Honest Interview #shorts
# Buzz snap
# ------------
# The Road to Recovery: Overcoming Personal Injury | Hatching for Health Episode 10
# Hatching For Health
# ------------
# Storm Monroe TALKS Africa, Lap Dogs, HIV, Personal Health, Powda Head Stalkers &amp; Tasha K Regrets?
# Consciouz Tv
# ------------
# Soda vs Water: What Happens Inside Your Kidneys? 🥤💧
# Daily Life Health
# ------------
# AI-Driven Preventive Healthcare Launch Event - Your Personal Health Butler Is Now Online | LIVE4WELL
# LIVE4WELL
# ------------
# Chris Eubank Jr provides an update on his personal health battles on social media. 🙏
# Boxing Social
# ------------
# Major personal health update | healing isn’t linear ❤️‍🩹
# Julia McCoy
# ------------
# AI in Healthcare Series: AI as Your Personal Health Partner
# Stanford Online
# ------------
# Full kesehatan pribadi
# Mlbb only
# ------------
# Free personal health companion. Ask any health question, review your labs, optimize your health
# MaxTalksTech
# ------------
# 217lbs Down. 2 Surgeries Later. Still Standing Strong 👑 | QUEEN MACHINE
# KING MOTIV8
# ------------
# AI-Powered Personal Health Support | Ayuda Health
# Ayuda Health
# ------------
# Điều gì xảy ra khi bạn không ăn bất cứ thứ gì trong 24 giờ? Tập 1 - #Shorts
# Sức Sống 360
# ------------
# Harrison Smith Feeds the Local Media Jackals, Talks Personal Health Issue
# Purple FTW! Podcast
# ------------
# A Personal Health Share That Might Help You
# Thais Gibson - Personal Development School
# ------------
# Individual VS Family Floater Health Insurance  | WHICH ONE IS BETTER ? | Gurleen Kaur Tikku
# Gurleen Kaur Tikku
# ------------
# Having a personal health insurance policy means you own your own health cover.
# OneInsure
# ------------
# Trump talks personal health as premiums rise for millions of Americans
# THV11
# ------------
# the number one anti-aging vegetable in the world 🌿 health
# 3 Minute Health
# ------------
# No Stream Today Personal Health First. Have A Great Weekend
# BUCH'D UP
# ------------
# Google&#39;s New Fitbit Personal Health Coach Is Pretty Useful...
# Jaime Rivera
# ------------
# Sitting Too Long Is Harming Your Gut | Medical 3D Reveal
# medi shorts
# ------------
# march personal curriculum | plan with me, march TBR, health goals
# Mind Body Mel
# ------------
# AI-Powered Wellness: Your Personal Health Coach
# CGTN Podcasts
# ------------
# Why a Personal Health Choice Shouldn’t Lead to Online Hate
# courd3210
# ------------
# Corporate Health Cover vs Personal Policy | Biggest Insurance Mistake Employees Make
# Telugu Assets
# ------------
# chat 🤝all of our personal health questions #chatgpt #unhinged #2025
# Gals On The Go Podcast
# ------------
# GOOD VIBRATIONS PODCAST, VOL  268   CLIVE DE CARLE  - PERSONAL HEALTH SOVEREIGNTY (RELOAD FROM 2025)
# Mark Devlin
# ------------
# JPT Personal Health Club
# JPT Personal Health Club
# ------------
# Young entrepreneur turns personal health issue into business venture
# Caribbean Broadcasting Corporation
# ------------
# অতিরিক্ত কাঠবাদাম খেলে আপনার কি ক্ষতি হতে পারে  #dr_joynal_abdin #motivation
# Dr. Md. Joynal Abdin
# ------------
# Turning Lab Results Into Your Personal Health Roadmap
# TopHealth
# ------------
# Is Corporate Health Insurance Enough? | Personal vs Corporate Health Insurance 2025 | HalfMapped
# Half Mapped | AaruShivam
# ------------
# india| VitaWear SmartBand: Your Personal  Health Partner| #viral #shortsfeed #comedyshorts
# 🥇 GrevoFX
# ------------
# Imran Khan’s Health and Access to Personal Medical Care!
# Geo News
# ------------
# The ripple effect of sharing a personal health scare is truly astonishing! 😮
# Mindful Michelle
# ------------
# ইফতারিতে কোন তিনটি খাবার খেলে আপনার শরীর ভালো
# Dr. Md. Joynal Abdin
# ------------
# Focussing on personal health and I need an operation - Dupreyten’s Contracture
# GetawayGeese
# ------------
# Sophie Cunningham GOING VIRAL Opens Up About a Deeply Personal Health Issue (No Filter)
# The Facts Drone
# ------------
# Comment ➡️ “Fast” to tell you how to join my personal health community.
# Jarc
# ------------
# AI Health Tips | Daily Simple Health Advice for Better Life #Shorts
# Developer Mujahid
# ------------
# STRESS how it affects your personal HEALTH, WEALTH &amp; HAPPINESS
# The Alchemy of Stress
# ------------
# Sai Rithu Breaks Down: Pandian Stores 2 Actress Shares Her Personal Health Battle😢| Emotional Speech
# Yaazh Tamizh
# ------------
# Kaunsa Health Insurance lena chahiye? Personal Health Insurance | Family Health Insurance | Ditto
# Ditto Insurance Hindi
# ------------
# PRAYERS! King Charles II  Shares Personal Health Update | Very Touching 😭🙏
# DIGITAL MEDIA
# ------------
# Personal Health Update - Temporary Impact to MO Chad Channel
# MO Chad
# ------------
# പബ്ലിക് ടോയ്‌ലറ്റിൽ വച്ച് menstrual cup വയ്ക്കരുത് 🩸#hygene #health #personal #medical
# Med Vibes by Asha Mano
# ------------
# सिर्फ Corporate Health Policy काफी नहीं! Personal Policy क्यों ज़रूरी है? #shortvideo #trending
# GRP Insure Invest
# ------------
# Group vs Personal Health Insurance | Beshak
# Beshak Insurance
# ------------
# Appalachian History: personal Choice Doesn’t Explain Health Challenges
# Dr Caseys Home and Garden
# ------------
# 뼈를 녹이는 채소! 식탁에서 당장 치우세요!
# 인생친구
# ------------
# Can Marco Kasper find his game again? + A Personal Health Channel Update | 7 Minute Wings
# Red Wings Report by Strings'npucks
# ------------
# The REAL Difference Between Self Care and Doctor&#39;s Orders for Optimal Health
# Health Cartoon Corner
# ------------
# I Was Wrong About Everything (Personal Health Journey)
# Zireal
# ------------
# Dark Psychology for personal health | Motivation | Dark Facts
# MianX
# ------------
# The ONLY personal health coach YOU NEED. I can help with anything! #healthandwellnesscoaching
# Madame Homeostasis
# ------------
# Should Personal Health Choices Be Exempt from Accountability? This Takes a Hard Stance!
# Conservative Column
# ------------
# Technology is Making Health Personal
# Health Uncensored With Dr. Drew
# ------------
# 💍 Introducing the RONC Smart Ring – Your Personal Health Companion
# RONC Smart
# ------------
# Your personal health
# universal health
# ------------
# Dialysis Reality: My Personal Health Struggle and Fear #shorts
# Becoming Epic Podcast
# ------------
# Wellness is the active pursuit of personal health.
# Chef LeeZ
# ------------
# Lift AI, where ai and personal health come together #AI #innovation #useliftai #liftai #x4btc
# Good Food Good Health
# ------------
# Doctor reveals how lab &#39;normal&#39; is secretly misleading you #health #medical #labwork
# Overhook Health
# ------------
# Natural Teas That Actually Work! #echohub #healthtips #ytshorts#herbal #tea #trending
# EchoHub
# ------------
# A FIRE THAT NEVER DIES! OTR DRIVER&#39;S PERSONAL HEALTH CONCERN #otrlife #otrdriver #fissuretreatment
# BIG BELLY AND SON TRUCKING
# ------------
# Meet your personal health coach of 2025 👉 #GalaxyWatch8
# Samsung Canada
# ------------
# Expert slams reliance on AI for personal health information
# The Tech Report
# ------------
# This is no longer just a toothbrush, it’s your personal health node 📌
# BrushO Network
# ------------
# Chris Hemsworth Shares Personal Health Update 💙🌍 ||#chrishemsworth#hollywoodnews @CelebTune-fppp
# CelebTune
# ------------
# Agar aap Paan Masala roz khana shuru kar do toh kya hoga? #facts #vimal #cancer #shorts #didyouknow
# Kivo Films
# ------------
# When Medical Advice Becomes Dangerous (A Personal Story)
# Rachel Richards Massage
# ------------
# Prayer for Personal Health
# Phinsen Daniel
# ------------
# PERSONAL HEALTH INSURANCE #financetips #financialmiracle #entrepreneur #financialfreedom
# Sunilkumar Bhaskaran
# ------------
# Decide sobre tu información personal #health,#healthinsurance,#medicareadvantage, #medicarebenefits
# Hablemos Medicare
# ------------
# Why have personal health insurance even when you’ve have corporate mediclaim?
# Ravinder Singh
# ------------
# Nick Jonas: Inspiring Personal Health Battle! #NickJonas #DiabetesWarrior
# Inside Story
# ------------
# Personal Health Plan vs Employer Plan: Which One Actually Wins? #employeebenefits #healthinsurance
# BlackIron
# ------------
# New Moms ke liye Powerful Moringa Soup | Post Delivery Health Support #healthfocus #newmomsupport
# Meri Sakhi Healthy Food Channel
# ------------
# Most Men Prioritize their Cars to Personal Health
# Dr. Brad Kobsar
# ------------
# INDIAN FINEST UROLOGIST ON MEN&#39;S PERSONAL HEALTH #urology #menhealth #nofilterwithnik
# No Filter With Nik - Shorts
# ------------
# They turned a personal health crisis into an ACCREDITED education empire! 🤯 You won&#39;t believe th...
# Master Phil
# ------------
# Be intentional about personal health/hygiene and self development  #Ppteaching#drprincebuma
# DR. PRINCE BUMA
# ------------
# Gail Moerane how Personal Health Pathways changed her life
# DiscoverySA
# ------------
# proudP   Personal Urinary Health Monitor
# proudP: Urine Flow Test
# ------------
# Personal Hygiene Tips for men #drvenkatsubramaniam #drvenkat #urology #healthtips  #health #trend
# Dr.Venkatsubramaniam
# ------------
# The #1 Mistake Killing Home Health Agencies... AI Makes Care MORE Personal?! (Shocking Truth)
# Copper Digital
# ------------
# Your personal health coach is now Al!Smarter fitness, better health !! #FitnessAl #Healthcare #fit
# CareeTips
# ------------
# We Make It Personal - Stroke Care at Orlando Health
# Orlando Health
# ------------
# AI and Mental Health: Why Personal Use May Be Linked to Depression
# UroNurse
# ------------
# Mental health and well-being personal retreats
# Douglas Baker
# ------------
# 🧡  Orange Foods &amp; What They Support
# Elders Living Better
# ------------
# How Fitbit Redefined Personal Health Tracking. #Shorts #VidNarrate
# mc blessed TV
# ------------
# ✨✨Mi Lifestyle#Health#Personal#Skin#Agro Care#Products#Likes#Subscribe✨✨
# Sivaa_official
# ------------
# Katura Health – Caring like it’s personal, because it is.  Find a Caregiver Near You&quot;
# Katura Health
# ------------
# The Personal Impact on Behavioral Health Workers
# OhioDBH
# ------------
# ЛИЧНЫЕ ПРИВЫЧКИ ДЛЯ ДИСЦИПЛИНЫ
# Доктор Глазков Юрий. Лечение суставов.
# ------------
# డబ్బు నీళ్లలాంటిది  #MoneyMindset #PersonalFinance #MoneyWisdom #FinancialEducation #SmartMoney
# Telugu Assets
# ------------
# 北海道大学病院パーソナルヘルスセンター　PHC：Personal Health Cnter　🧬ゲノム解析ウェルネスプラン　人間にもまた、それぞれの「体質」というテロワールがあります。
# 中村雅人
# ------------
# Build a &quot;Personal Ecosystem&quot; for Health
# theathletetech
# ------------
# concept of health trough personal story - Feb 23,2026
# Samuel Salnikov - coral club
# ------------
# The Personal Health Companion Revolution
# New Next Era
# ------------
# Personal News  &amp; Health Update
# DATC Media Company
# ------------
# We Make It Personal - Orlando Health Jewett Orthopedic Institute Celebrates 1-Year Anniversary
# Orlando Health
# ------------
# ​​Healthy life By Viriyah Health Advisory EP.43 &quot;Personal check-up เจาะลึกการตรวจสุขภาพอย่างตรงจุด&quot;
# Viriyah Health Insurance - วิริยะประกันสุขภาพ
# ------------
# Healthcare leadership at Endeavor Health: Katie McGovern on safe, seamless and personal care
# Endeavor Health
# ------------
# Bruce Campbell Shares Emotional Health Update
# Trending Mania
# ------------
# V5.0 favors node health, not luck! 🔥Personal node health #InterLink #ITLG #ITL
# raj chaitanya
# ------------
# Local farmer, rancher shares personal connection to promote awareness for mental health in the ag...
# WIBW 13 NEWS | Topeka, KS
# ------------
# Piden al  personal de salud que demuestre por qué faltó durante jornada de violencia en Jalisco
# Dirmedal
# ------------
# Introducing Infiuss Health&#39;s Digital patient twins for personal health optimisation
# Infiuss Health
# ------------
# Personal Health Neglect করলে শরীরে কী হয়? চমকে উঠবেন!
# Dr. Moumita Health Guide
# ------------

# %%
# Verify search returned results
n = len(response["items"])
if n > 0:
    print(f"Received {n} video results from paginated search.")
else:
    print("No video results returned.")
# Out:
# Received 129 video results from paginated search.

# %% [markdown]
# ## Stage 2: Transcript Extraction
#
# Video IDs are extracted from the search response, passed to the transcript API, and saved per-video to `data/transcripts/raw/{video_id}.json` and `data/transcripts/cleaned/{video_id}.txt`.

# %% [markdown]
# ### Fetch Video IDs from Search Response

# %%
query_video_ids = []

# For each search result
for item in response["items"]:
    query_video_ids.append(item["id"]["videoId"])

# Print for validation
print(f"TOTAL # of Video IDs: {len(query_video_ids)}")

print("Sample First 5 Video IDs:\n-----------")
for i in range(0, 5):
    print(query_video_ids[i])
# Out:
# TOTAL # of Video IDs: 129
# Sample First 5 Video IDs:
# -----------
# 0fb7SsSIlqM
# MZ65Z8papwg
# 9Zz6Nj0xwXM
# gpzDxm7qflY
# kRLWY-u52jU

# %% [markdown]
# ### Filtering for High-Impact Videos
# For each video in queried set of IDs, check the video atttributes to filter only high-impact videos.
# - We set the criterion here so we need to justify that.
# - Return a subset of original queried IDs which fulfil the criterion.

# %%
def chunk_video_ids(lst, n):
    """Breaks down any input series of video_ids into smaller subset of lists. Going to be useful to handle API request limits."""
    for i in range(0, len(lst), n):
        yield lst[i : i + n]


def fetch_video_metadata(youtube, video_ids):
    """Helper function to get hydrated set of video metrics beyond search"""
    all_items = []

    for job in chunk_video_ids(video_ids, 50):
        resp = (
            youtube.videos()
            .list(
                part="snippet,statistics,contentDetails",
                id=",".join(job),
                maxResults=50,
            )
            .execute()
        )

        all_items.extend(resp.get("items", []))

    return all_items

# %%
video_mds = fetch_video_metadata(youtube, query_video_ids)
print(len(video_mds), video_mds[0].keys())
# Out:
# 129 dict_keys(['kind', 'etag', 'id', 'snippet', 'contentDetails', 'statistics'])

# %%
print("ContentDetails:")
pprint(video_mds[0]["contentDetails"])

print("\nStatistics")
pprint(video_mds[0]["statistics"])

print("\nSnippet")
pprint(video_mds[0]["snippet"])
# Out:
# ContentDetails:
# {'caption': 'false',
#  'contentRating': {},
#  'definition': 'hd',
#  'dimension': '2d',
#  'duration': 'PT18M13S',
#  'licensedContent': True,
#  'projection': 'rectangular'}
#
# Statistics
# {'commentCount': '961',
#  'favoriteCount': '0',
#  'likeCount': '13872',
#  'viewCount': '365673'}
#
# Snippet
# {'categoryId': '27',
#  'channelId': 'UCwAdQUuPT6laN-AQR17fe1g',
#  'channelTitle': 'Pranjal Kamra',
#  'defaultAudioLanguage': 'hi',
#  'defaultLanguage': 'en-IN',
#  'description': 'Compare Best Health Plans with Ditto: '
#                 'https://ditto.sh/6zwj4x \n'
#                 '\n'
#                 'After the GST reforms, many of you asked us to bring back our '
#                 'annual insurance recommendation video early, so we’re back, '
#                 'starting with the Best Health Insurance Plans for 2026. \n'
#                 '\n'
#                 'In this video, we reveal the Best Health Insurance Plans for '
#                 '2026, shortlisted through a transparent and data-backed '
#                 'process from 31 insurers across India. It’s a carefully '
#                 'researched framework designed to help you protect your family '
#                 'without falling for sales traps or half-baked advice.\n'
#                 '\n'
#                 'Here’s how we selected the top insurers:\n'
#                 '\n'
#                 '1. Claim Settlement Ratio (CSR)\n'
#                 '2. Incurred Claims Ratio (ICR)\n'
#                 '3. Complaints Ratio\n'
#                 '4. Network Hospitals\n'
#                 '\n'
#                 'After applying these filters, we arrived at our Top 3 Health '
#                 'Insurance Plans for 2026, each tailored for a different kind '
#                 'of policyholder. Whether you’re buying your first policy, '
#                 'managing chronic conditions, or looking for a simple digital '
#                 'plan, this video will help you decide confidently.\n'
#                 '________________________________________________________________________________________\n'
#                 '\n'
#                 'Get in Touch: \n'
#                 '⏩ Email Us - support@finology.in\n'
#                 '🌐 Website - https://www.finology.in/\n'
#                 '📞 For queries, contact - 022-489-66660\n'
#                 '_________________________________________________________________________________________\n'
#                 '\n'
#                 '➡️ Join my WhatsApp channel: '
#                 'https://whatsapp.com/channel/0029Va8O...\n'
#                 '\n'
#                 '➡️Open your demat account on Zerodha:  '
#                 'https://zerodha.com/open-account?c=ZM... \n'
#                 '\n'
#                 '➡️Buy Investonomy: https://amzn.to/4jkeM09\n'
#                 '_________________________________________________________________________________________\n'
#                 '\n'
#                 'Disclaimer: Mutual fund investments are subject to market '
#                 'risks. Read all scheme-related documents carefully before '
#                 'investing. This content is not investment advice or a '
#                 'recommendation. Past performance does not guarantee future '
#                 'results. Data, expense ratios, portfolio holdings, and '
#                 'riskometer classification can change. Viewers should conduct '
#                 'their own research and consult a registered investment '
#                 'adviser before making any investment decisions. \n'
#                 '\n'
#                 'Disclosure: Mr Pranjal Kamra, the Director of Finology '
#                 'Ventures Private Limited, is a SEBI-registered investment '
#                 'Adviser with registration No: INA000012218. He further '
#                 'confirms that he does not hold any beneficial ownership or '
#                 'interest in the securities discussed, nor has he received any '
#                 'compensation related to the views expressed.',
#  'liveBroadcastContent': 'none',
#  'localized': {'description': 'Compare Best Health Plans with Ditto: '
#                               'https://ditto.sh/6zwj4x \n'
#                               '\n'
#                               'After the GST reforms, many of you asked us to '
#                               'bring back our annual insurance recommendation '
#                               'video early, so we’re back, starting with the '
#                               'Best Health Insurance Plans for 2026. \n'
#                               '\n'
#                               'In this video, we reveal the Best Health '
#                               'Insurance Plans for 2026, shortlisted through a '
#                               'transparent and data-backed process from 31 '
#                               'insurers across India. It’s a carefully '
#                               'researched framework designed to help you '
#                               'protect your family without falling for sales '
#                               'traps or half-baked advice.\n'
#                               '\n'
#                               'Here’s how we selected the top insurers:\n'
#                               '\n'
#                               '1. Claim Settlement Ratio (CSR)\n'
#                               '2. Incurred Claims Ratio (ICR)\n'
#                               '3. Complaints Ratio\n'
#                               '4. Network Hospitals\n'
#                               '\n'
#                               'After applying these filters, we arrived at our '
#                               'Top 3 Health Insurance Plans for 2026, each '
#                               'tailored for a different kind of policyholder. '
#                               'Whether you’re buying your first policy, '
#                               'managing chronic conditions, or looking for a '
#                               'simple digital plan, this video will help you '
#                               'decide confidently.\n'
#                               '________________________________________________________________________________________\n'
#                               '\n'
#                               'Get in Touch: \n'
#                               '⏩ Email Us - support@finology.in\n'
#                               '🌐 Website - https://www.finology.in/\n'
#                               '📞 For queries, contact - 022-489-66660\n'
#                               '_________________________________________________________________________________________\n'
#                               '\n'
#                               '➡️ Join my WhatsApp channel: '
#                               'https://whatsapp.com/channel/0029Va8O...\n'
#                               '\n'
#                               '➡️Open your demat account on Zerodha:  '
#                               'https://zerodha.com/open-account?c=ZM... \n'
#                               '\n'
#                               '➡️Buy Investonomy: https://amzn.to/4jkeM09\n'
#                               '_________________________________________________________________________________________\n'
#                               '\n'
#                               'Disclaimer: Mutual fund investments are subject '
#                               'to market risks. Read all scheme-related '
#                               'documents carefully before investing. This '
#                               'content is not investment advice or a '
#                               'recommendation. Past performance does not '
#                               'guarantee future results. Data, expense ratios, '
#                               'portfolio holdings, and riskometer '
#                               'classification can change. Viewers should '
#                               'conduct their own research and consult a '
#                               'registered investment adviser before making any '
#                               'investment decisions. \n'
#                               '\n'
#                               'Disclosure: Mr Pranjal Kamra, the Director of '
#                               'Finology Ventures Private Limited, is a '
#                               'SEBI-registered investment Adviser with '
#                               'registration No: INA000012218. He further '
#                               'confirms that he does not hold any beneficial '
#                               'ownership or interest in the securities '
#                               'discussed, nor has he received any compensation '
#                               'related to the views expressed.',
#                'title': 'Best Health Insurance Plans 2026'},
#  'publishedAt': '2025-10-28T13:24:43Z',
#  'tags': ['pranjal kamra',
#           'finology',
#           'value investing',
#           'stock market for beginners',
#           'stock market tutorial',
#           'value investing for beginners',
#           'stock market in india',
#           'best health insurance plan',
#           'health insurance',
#           'health insurance policy for family',
#           'health insurance policy for 2026',
#           'health insurance policy for parents',
#           'share market for beginners',
#           'health insurance plan for family'],
#  'thumbnails': {'default': {'height': 90,
#                             'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/default.jpg',
#                             'width': 120},
#                 'high': {'height': 360,
#                          'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/hqdefault.jpg',
#                          'width': 480},
#                 'maxres': {'height': 720,
#                            'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/maxresdefault.jpg',
#                            'width': 1280},
#                 'medium': {'height': 180,
#                            'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/mqdefault.jpg',
#                            'width': 320},
#                 'standard': {'height': 480,
#                              'url': 'https://i.ytimg.com/vi/0fb7SsSIlqM/sddefault.jpg',
#                              'width': 640}},
#  'title': 'Best Health Insurance Plans 2026'}

# %%
print(f"Snippet Keys: {video_mds[0]['snippet'].keys()}")
# Out:
# Snippet Keys: dict_keys(['publishedAt', 'channelId', 'title', 'description', 'thumbnails', 'channelTitle', 'tags', 'categoryId', 'liveBroadcastContent', 'defaultLanguage', 'localized', 'defaultAudioLanguage'])

# %% [markdown]
# - Factors from Videos.list() to add to video DB schema:
#     - Snippet: `categoryId`
#     - Statistics:  `commentCount, likeCount, viewCount`
#     - ContentDetails: `duration`

# %%
### Compute Engagement Metrics for Filtration of Records
from datetime import datetime, timezone
import math


def compute_impact_features(vid_metadata):
    """Provided a video dictionary from videos().list() --> we want to return a dict with derived impact features."""

    stats = vid_metadata.get("statistics", {})
    snippet = vid_metadata.get("snippet", {})

    # Raw Engagement Data
    view_count = int(stats.get("viewCount", 0))
    comment_count = int(stats.get("commentCount", 0))
    like_count = int(stats.get("likeCount", 0))
    published_at = datetime.fromisoformat(snippet["publishedAt"].replace("Z", "+00:00"))
    days_since = max(
        (datetime.now(timezone.utc) - published_at).days,
        1,  # avoid divide-by-zero
    )

    # Derived metrics from API provided data
    views_per_day = view_count / days_since
    comments_per_1kviews = (
        ((comment_count / view_count) * 1000) if view_count > 0 else 0
    )
    likes_per_1kviews = ((like_count / view_count) * 1000) if view_count > 0 else 0

    # Metric weightage (impact score calculation)
    reach = math.log10(view_count + 1)
    momentum = math.log10(views_per_day + 1)

    # Normalized engagement scores
    engagement = math.log10(comments_per_1kviews + 1) + math.log10(
        likes_per_1kviews + 1
    )
    impact_score = 0.45 * reach + 0.35 * momentum + 0.20 * engagement

    return {
        "video_id": vid_metadata["id"],
        "view_count": view_count,
        "views_per_day": views_per_day,
        "comments_per_1kviews": comments_per_1kviews,
        "likes_per_1kviews": likes_per_1kviews,
        "impact_score": impact_score,
    }

# %%
# Percentile-Based Filtering --> accomodates for cases when number of videos per call vary, so the cutoff is malleable with respect to video ids pulled.
def filter_ws_by_percentile(scored_videos, percentile=0.9):
    """
    Keeps videos above the given percentile of impact_score.
    Example: percentile=0.9 keeps top 10%.
    """

    if not scored_videos:
        return []

    # Sort by impact_score descending
    scored_videos.sort(key=lambda x: x["impact_score"], reverse=True)

    cutoff_index = int(len(scored_videos) * percentile)

    # Prevent empty return
    cutoff_index = min(cutoff_index, len(scored_videos) - 1)
    threshold_score = scored_videos[cutoff_index]["impact_score"]

    filtered = [v for v in scored_videos if v["impact_score"] >= threshold_score]

    return filtered

# %%
MIN_COMMENTS_PER_1K = 2.5  # 0.25%
MIN_LIKES_PER_1K = 25  # 2.5%
MIN_VIEWS = 1000

# Calculated each video's eval metrics
video_impact_metrics = [compute_impact_features(v) for v in video_mds]

fails_like = sum(v["likes_per_1kviews"] < 25 for v in video_impact_metrics)
fails_comment = sum(v["comments_per_1kviews"] < 2.5 for v in video_impact_metrics)
fails_both = sum(
    (v["likes_per_1kviews"] < 25) and (v["comments_per_1kviews"] < 2.5)
    for v in video_impact_metrics
)

print("total:", len(video_impact_metrics))
print("fails_like:", fails_like)
print("fails_comment:", fails_comment)
print("fails_both:", fails_both)

# Skip low-engagement / low-reach videos
eligible_videos = [
    v
    for v in video_impact_metrics
    if (
        v["view_count"] >= MIN_VIEWS
        and v["comments_per_1kviews"] >= MIN_COMMENTS_PER_1K
        and v["likes_per_1kviews"] >= MIN_LIKES_PER_1K
    )
]

# Filter for top 10%
high_impact_videos = filter_ws_by_percentile(eligible_videos, percentile=0.90)

# Return final set of eligible video IDs
filtered_video_ids = [v["video_id"] for v in high_impact_videos]

print(f"Eligible Videos:{len(eligible_videos)}")
print(f"High Impact Videos:{len(high_impact_videos)}")
print(f"Final Filtered Video IDs:{len(filtered_video_ids)}")
# Out:
# total: 129
# fails_like: 82
# fails_comment: 94
# fails_both: 73
# Eligible Videos:19
# High Impact Videos:18
# Final Filtered Video IDs:18

# %% [markdown]
# ### Extract and Clean Transcripts
# - Use external YT Transcripts API for 2-stage data ingestion
# - Defined a helper function to collapse JSON structure and remove noise; resulting cleaned transcript is stored as a .txt object.

# %%
# clean_transcript defined in imports cell above
def clean_transcript(transcript_data: Union[List[Dict], str]) -> str:
    """
    Clean a YouTube transcript by removing noise and formatting artifacts into .txt blob.
    """
    if isinstance(transcript_data, str):
        text = transcript_data
    else:
        text = " ".join([item.text for item in transcript_data])
    text = re.sub(r"^>\s*", "", text, flags=re.MULTILINE)
    text = re.sub(r"(?:^|\s)(?:[A-Z][a-z]*(?:\s+[A-Z][a-z]*)?)\s*:\s*", " ", text)
    text = re.sub(r"\[[^\]]*\]", "", text, flags=re.IGNORECASE)
    text = re.sub(r"\([^)]*\)", "", text)
    for pattern in [
        r"\b(?:um|uh|ugh|hmm)\b",
        r"\byou\s+know\b",
        r"\blike\b(?=\s+(?:he|she|they|it|the|a|i))",
    ]:
        text = re.sub(pattern, "", text, flags=re.IGNORECASE)
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\s+([.,!?;:])", r"\1", text)
    text = re.sub(r"([.!?])\s+(?=[a-z])", lambda m: m.group(1) + " ", text)
    text = text.strip()
    if text and text[0].islower():
        text = text[0].upper() + text[1:]
    return text

# %% [markdown]
# ***We need to add Supabase DB store implementation here (transcripts: raw + cleaned).***

# %%
ytt_api = YouTubeTranscriptApi()
formatter = JSONFormatter()

(DATA_ROOT / "transcripts" / "raw").mkdir(parents=True, exist_ok=True)
(DATA_ROOT / "transcripts" / "cleaned").mkdir(parents=True, exist_ok=True)

print(f"Number of candidate video IDs to evaluate: {len(filtered_video_ids)}")

for video_id in filtered_video_ids:
    try:
        raw_transcript = ytt_api.fetch(video_id)
        json_formatted = formatter.format_transcript(raw_transcript, indent=2)
        (DATA_ROOT / "transcripts" / "raw" / f"{video_id}.json").write_text(
            json_formatted, encoding="utf-8"
        )
        cleaned = clean_transcript(raw_transcript)
        (DATA_ROOT / "transcripts" / "cleaned" / f"{video_id}.txt").write_text(
            cleaned, encoding="utf-8"
        )
    except Exception:
        print(f"No transcript available for Video ID: {video_id}")
# Out:
# Number of candidate video IDs to evaluate: 18
# No transcript available for Video ID: 0fb7SsSIlqM
# No transcript available for Video ID: t0hBbNYGqlo
# No transcript available for Video ID: z8RlBfAqe3M
# No transcript available for Video ID: k3iXE4Bv2mE

# %% [markdown]
# ***We need to add Supabase DB store implementation here (comments).***

# %%
import json

(DATA_ROOT / "comments").mkdir(parents=True, exist_ok=True)

for video_id in filtered_video_ids:
    try:
        all_items = []
        page_token = None
        while True:
            resp = (
                youtube.commentThreads()
                .list(
                    part="snippet,replies",
                    videoId=video_id,
                    order="relevance",
                    maxResults=100,
                    pageToken=page_token,
                )
                .execute()
            )
            all_items.extend(resp.get("items", []))
            page_token = resp.get("nextPageToken")
            if not page_token:
                break
        (DATA_ROOT / "comments" / f"{video_id}.json").write_text(
            json.dumps({"items": all_items}, indent=2), encoding="utf-8"
        )
    except Exception:
        pass

# %%
# Validate data that is being stored in the directories for now; make sure we have the same # of entries in both subidrectories (raw - cleaned)
raw_count = len(
    [p for p in (DATA_ROOT / "transcripts" / "raw").iterdir() if p.is_file()]
)
cleaned_count = len(
    [p for p in (DATA_ROOT / "transcripts" / "cleaned").iterdir() if p.is_file()]
)

if raw_count == cleaned_count:
    print(f"Verification successful: {raw_count} files in both directories.")
else:
    print(f"Mismatch: {raw_count} raw files, {cleaned_count} cleaned files.")
# Out:
# Verification successful: 14 files in both directories.
