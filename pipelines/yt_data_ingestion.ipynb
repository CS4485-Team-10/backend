# %% [markdown]
# # **YouTube Data Ingestion Pipeline**
#
# This notebook accomplishes the following:
# 1. Pull official YouTube metadata via Google's YouTube Data API
# 2. Pull transcripts via an external API, provided a video ID

# %% [markdown]
# ## Import Libraries and Environment Variables

# %%
import os
import re
import shutil
from pathlib import Path
from dotenv import load_dotenv
from googleapiclient.discovery import build
from typing import Union, List, Dict
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter

def clear_data_dirs():
    """Clear subdirectories: metadata, transcripts/cleaned, transcripts/raw."""
    dirs = [
        Path("data/metadata"),
        Path("data/transcripts/cleaned"),
        Path("data/transcripts/raw"),
    ]
    for d in dirs:
        if d.exists():
            shutil.rmtree(d)
        d.mkdir(parents=True, exist_ok=True)
    
# Initialize by cleaning data directories using function above...
clear_data_dirs()

# %%
# Load .env file
load_dotenv()
YT_API_KEY = os.getenv("YOUTUBE_DATA_API_KEY")

# %% [markdown]
# ## Stage 1: Query Video IDs from YouTube Data API

# %%
"""
- Build a service object with appropriate credentials to pull data from YouTube, with the following constraints:
    - Ordering query results by view count (greatest to least)
    - Time frame limited to last 6 months
"""

youtube = build(serviceName="youtube", version="v3", developerKey=YT_API_KEY)

# %%
from datetime import datetime, timedelta, timezone
six_months_ago = (datetime.now(timezone.utc) - timedelta(days=180)).strftime("%Y-%m-%dT00:00:00Z")

# Returns a nested dictionary
response = youtube.search().list(
    q="personal health",
    part="snippet",
    type="video",
    maxResults=50,
    publishedAfter = six_months_ago,
    order="viewCount"
).execute()

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# - Previewing nested dictionary structure & relevant attributes for feature selection
#     -  `response["items]`: list of search results (each formatted as a dict)
#
#
#
#
#
# - Response attributes which aren't useful beyond validation:
#     - `'kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo'`

# %%
# if it's a plain dict-like thing
print(f"Dictionary Structure:\n{response.keys()}")

from pprint import pprint
print("\nFull Response Dictionary Structure:\n")
pprint(response)
# Out:
# Dictionary Structure:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])
#
# Full Response Dictionary Structure:
#
# {'etag': 'YxNML7ShnfAJpHnM6Uosq-WMrNI',
#  'items': [{'etag': 'pYlb4rucx4JLJoHW1kvP9pwjvoo',
#             'id': {'kind': 'youtube#video', 'videoId': 'MHv-qEhCstA'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCBQJKez34g7jkSoH3_noUaQ',
#                         'channelTitle': 'CineeVerge',
#                         'description': 'Manthena Satyanarayana Raju | '
#                                        'Naturopathy Lifestyle | No Soap For 35 '
#                                        'Years | Tongue Cleaning Secret | '
#                                        'Personal Hygiene ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-13T02:30:05Z',
#                         'publishedAt': '2026-01-13T02:30:05Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Health Expert Manthena Satyanarayana Raju '
#                                  'Reveals Shocking 35-Year Personal Hygiene '
#                                  'Habits'}},
#            {'etag': 'KlYrfCvaX4TnBpqBR2Kf6uE2pI4',
#             'id': {'kind': 'youtube#video', 'videoId': '-rscIfp-HW4'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC23C7y9RDTpyt3wwH9qcRlA',
#                         'channelTitle': 'Osama Tayyab Podcast ',
#                         'description': 'Discover expert insights into complete '
#                                        "women's health solutions with Dr. "
#                                        'Jamil Mehravi. From nutrition and '
#                                        'lifestyle to mental ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-05T14:05:06Z',
#                         'publishedAt': '2025-12-05T14:05:06Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/-rscIfp-HW4/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/-rscIfp-HW4/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/-rscIfp-HW4/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Complete Women’s Health Solutions | Ft. Dr. '
#                                  'Jamil Mehravi With Osama Tayyab'}},
#            {'etag': '4EYsotyMZ1T2vSE_pRR1CAp9oeE',
#             'id': {'kind': 'youtube#video', 'videoId': 'FpDWFoHOzi0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCYWnJRF8gb1vQfGmEHYEKZQ',
#                         'channelTitle': 'The Hook',
#                         'description': 'cillianmurphy #steve #netflix '
#                                        '#mentalhealth.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-09-19T17:00:31Z',
#                         'publishedAt': '2025-09-19T17:00:31Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/FpDWFoHOzi0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/FpDWFoHOzi0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/FpDWFoHOzi0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Cillian Murphy on how he personally and his '
#                                  'advice for those struggling with their '
#                                  'mental health'}},
#            {'etag': 'D4pSOlVt35MSUECG-HPXWtVw7YQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'OwauZygLH_Q'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCSUi3x8uJ_zuy-arn2eDYVw',
#                         'channelTitle': 'Elen’s life USA',
#                         'description': 'This video/content was created with '
#                                        'the assistance of AI technology. '
#                                        'Disclaimer: All content and media on '
#                                        'this channel are for ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-06T05:20:14Z',
#                         'publishedAt': '2026-01-06T05:20:14Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/OwauZygLH_Q/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/OwauZygLH_Q/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/OwauZygLH_Q/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Եթե չեք ուզում քաղցկեղով հիվանդանալ #facts '
#                                  '#healthadvice #armeniatv #healthtips #help '
#                                  '#viral'}},
#            {'etag': '-vQXZqCxOibAGn1d0jl8hiSVRQI',
#             'id': {'kind': 'youtube#video', 'videoId': 'Aklx_zrToRs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCTR1Tk8SaMO9qw930kIOMHQ',
#                         'channelTitle': 'Sagar Sinha ',
#                         'description': 'Spam Free Health Insurance '
#                                        'https://ditto.sh/caok78 #partnership '
#                                        'In just the last one year, health '
#                                        'insurance claims worth ₹26000 ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-13T13:30:12Z',
#                         'publishedAt': '2025-12-13T13:30:12Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/Aklx_zrToRs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/Aklx_zrToRs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/Aklx_zrToRs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'How To Choose Best Health Insurance Plan In '
#                                  'India 2026 |\xa0SAGAR\xa0SINHA'}},
#            {'etag': 'fUjXKFpDq1VXuUQETSNRnhC7f_0',
#             'id': {'kind': 'youtube#video', 'videoId': 'KYLg0cvPZ5Y'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCHI8xE-za9g7lUu3JefJQ9Q',
#                         'channelTitle': 'River ',
#                         'description': 'A chat about the mysterious symptoms '
#                                        "I've been experiencing recently. My "
#                                        'Tip Jar for those who have kindly '
#                                        'asked: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-18T19:00:19Z',
#                         'publishedAt': '2025-11-18T19:00:19Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/KYLg0cvPZ5Y/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/KYLg0cvPZ5Y/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/KYLg0cvPZ5Y/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'A personal update about my health.'}},
#            {'etag': 'N0agwBeW0yvBhN4202PWr47Z1fQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'PzdlKn2h7Qs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC7M40BOCY2K4Yf_5wmtliAw',
#                         'channelTitle': 'Diana Kokku',
#                         'description': "I'd love to guide you through the "
#                                        'Bible. Join my community risk free! '
#                                        'Learn more: '
#                                        'https://www.biblestudy.co/bible-study '
#                                        'Get Your ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-26T15:00:45Z',
#                         'publishedAt': '2025-12-26T15:00:45Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/PzdlKn2h7Qs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/PzdlKn2h7Qs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/PzdlKn2h7Qs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Personal + Channel Update: Twin sister, '
#                                  'health and what&#39;s ahead!'}},
#            {'etag': 'ryhQp1nilIQVBOnW0RlDMecwKvU',
#             'id': {'kind': 'youtube#video', 'videoId': 'XnzoD1q6f_E'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZ_M7d3QwcRAV5Z9gLO1P0Q',
#                         'channelTitle': 'Aval Siru Megam',
#                         'description': 'This one is for every girl who wants '
#                                        'to feel confident, clean, and in '
#                                        'control of her body. In this episode '
#                                        'of my Glow-Up Challenge, ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-10T04:18:47Z',
#                         'publishedAt': '2026-01-10T04:18:47Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/XnzoD1q6f_E/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/XnzoD1q6f_E/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/XnzoD1q6f_E/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Personal Hygiene Glow-Up for Women|Body '
#                                  'Care, Menstrual Health &amp; Freshness Tips '
#                                  '#shorts #tamilshorts'}},
#            {'etag': 'RZNFf7sRcd0q1WSxmRbQYQVltBY',
#             'id': {'kind': 'youtube#video', 'videoId': 'kRLWY-u52jU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCXW8HfQr4dI1FMVHHmsEwyw',
#                         'channelTitle': 'LIVE4WELL',
#                         'description': 'AI-Driven Preventive Healthcare Launch '
#                                        'Event” wrapped up successfully one '
#                                        "week ago! We're deeply grateful for "
#                                        'the positive ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-03T12:11:45Z',
#                         'publishedAt': '2025-11-03T12:11:45Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/kRLWY-u52jU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Event Recap：AI-Driven Preventive Healthcare '
#                                  'Launch Event - Your Personal Health Butler '
#                                  'Is Now Online'}},
#            {'etag': 'WR3PcpMDF3nK-QQeVN87rOaapfo',
#             'id': {'kind': 'youtube#video', 'videoId': 'yjHW5qxfBj0'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCgsyJ5oeftrhdnpUIqsfexw',
#                         'channelTitle': 'Samantha',
#                         'description': 'In this episode of Take 20, join us as '
#                                        'we delve into the secrets of aging '
#                                        'well with Mona Sharma, a '
#                                        'world-renowned wellness coach ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-10T12:01:52Z',
#                         'publishedAt': '2026-02-10T12:01:52Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/yjHW5qxfBj0/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/yjHW5qxfBj0/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/yjHW5qxfBj0/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Art of Ageing Well. Samantha | Mona '
#                                  'Sharma'}},
#            {'etag': 'RQNdfa8eHbVMW5OcdW5rrqn89Kc',
#             'id': {'kind': 'youtube#video', 'videoId': 'pP0cCa7CbQo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCv_iDwcZUJH66i_QWpT_mqQ',
#                         'channelTitle': 'The Carpetbagger',
#                         'description': 'Intro by Cre80s '
#                                        'https://linktr.ee/cre80s If you would '
#                                        'like to make a contribution, my '
#                                        'Patreon can be found here ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-17T15:09:31Z',
#                         'publishedAt': '2026-02-17T15:09:31Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/pP0cCa7CbQo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Doctor&#39;s Appointment - My Personal '
#                                  'Health - Future Plans - Big Trip Coming'}},
#            {'etag': 'Yjh3PBvkvEYgmrBk_Bt01i9Cv9I',
#             'id': {'kind': 'youtube#video', 'videoId': '-XFUhGnwM4o'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCb4xzWE5X54RS421OUkcjLA',
#                         'channelTitle': 'The Donnie Simpson Show',
#                         'description': 'Singer/songwriter Will Downing sits '
#                                        'down with Donnie to discuss his '
#                                        'creative and personal journeys as he '
#                                        'works on his 29th ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-12T13:00:00Z',
#                         'publishedAt': '2025-11-12T13:00:00Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/-XFUhGnwM4o/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/-XFUhGnwM4o/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/-XFUhGnwM4o/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Will Downing on Staying True to His Sound, '
#                                  'Navigating Health &amp; Personal Loss, and '
#                                  'Resilience'}},
#            {'etag': 'Hv_6h0PIieZefhddqRwROrSUJYw',
#             'id': {'kind': 'youtube#video', 'videoId': 'zq2CPPASzhs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCDo6l8V0IObQC4lPgr2Jh9Q',
#                         'channelTitle': 'Sutter Health',
#                         'description': "At Sutter, we're always here. Find "
#                                        'care at https://www.sutterhealth.org/',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-13T18:42:44Z',
#                         'publishedAt': '2025-10-13T18:42:44Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/zq2CPPASzhs/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/zq2CPPASzhs/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/zq2CPPASzhs/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Pioneering &amp; Personal | Advanced Care | '
#                                  'Sutter Health'}},
#            {'etag': 'UjPJF3ef-o_DpxDrz6pn6gpejYQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'dcqCCTLC3uo'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC8WrThxRtrfupVw3iYow9ag',
#                         'channelTitle': 'Novelitedits',
#                         'description': 'Take care of yourself Shiori! '
#                                        '------------------------------------------------------------------------------------ '
#                                        'Watch the full VOD here! The Slow ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-20T11:30:24Z',
#                         'publishedAt': '2025-10-20T11:30:24Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/dcqCCTLC3uo/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Shiori Shares a Personal Health '
#                                  'Update【Hololive EN】'}},
#            {'etag': 'zUVati6rxfKS9PeIwYZaDD1KeDE',
#             'id': {'kind': 'youtube#video', 'videoId': 'e_wUjrlISrg'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC6Xt29Fi1ES6C1fEtWFUFIw',
#                         'channelTitle': 'Purple FTW! Podcast',
#                         'description': 'Minnesota Vikings safety Harrison '
#                                        'Smith Feeds the Local Media Jackals, '
#                                        'Talks Personal Health Issue. DONATION '
#                                        'LINKS Venmo: ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-09-10T20:33:30Z',
#                         'publishedAt': '2025-09-10T20:33:30Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/e_wUjrlISrg/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Harrison Smith Feeds the Local Media '
#                                  'Jackals, Talks Personal Health Issue'}},
#            {'etag': 'V7F0-gE1ailsUkqfr13boWcTx5M',
#             'id': {'kind': 'youtube#video', 'videoId': 'kQR4TsB7xe4'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC47wxgmBVmLHoe-sfAk2kBg',
#                         'channelTitle': 'Gözde Dgn',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T16:00:57Z',
#                         'publishedAt': '2026-02-23T16:00:57Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/kQR4TsB7xe4/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/kQR4TsB7xe4/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/kQR4TsB7xe4/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The doctor forwent personal accolades to '
#                                  'focus on healing the patient before him.'}},
#            {'etag': '-LgT09dgbz74jMykX1z0ZiDaV0E',
#             'id': {'kind': 'youtube#video', 'videoId': 'HavcD4WXktQ'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCfvEHu3IAJJF8JwdeZ8IlTA',
#                         'channelTitle': 'Dr. Tasnim Health Care',
#                         'description': 'Top 10 Health Benefits of Cardamom | '
#                                        'এলাচ খাওয়ার উপকারিতা | Weight Loss & '
#                                        'Heart Health Welcome to Dr.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-20T11:01:05Z',
#                         'publishedAt': '2026-02-20T11:01:05Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/HavcD4WXktQ/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/HavcD4WXktQ/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/HavcD4WXktQ/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Top 10 Health Benefits of Cardamom | এলাচ '
#                                  'খাওয়ার উপকারিতা | Weight Loss &amp; Heart '
#                                  'Health'}},
#            {'etag': 'DiLSX5b_G2GkEVc0KPxxu6boWek',
#             'id': {'kind': 'youtube#video', 'videoId': 'iWYwJRWZ0T4'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCsCJuXf5wwOV1sG3t50Q1Dg',
#                         'channelTitle': 'Healthy Empire',
#                         'description': 'Food is more than calories. The '
#                                        'nutrients you eat daily help your '
#                                        'organs function properly and support '
#                                        'long term wellness.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T18:43:42Z',
#                         'publishedAt': '2026-02-23T18:43:42Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/iWYwJRWZ0T4/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/iWYwJRWZ0T4/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/iWYwJRWZ0T4/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Foods as Medicine | Everyday Foods That '
#                                  'Support Your Heart, Brain, and Eyes'}},
#            {'etag': 'bdZJPC2CGZW4StZwY5YNRVnsksk',
#             'id': {'kind': 'youtube#video', 'videoId': 'UbwaJQLdeLk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCvixJtaXuNdMPUGdOPcY8Ag',
#                         'channelTitle': 'David Pakman Show',
#                         'description': 'trump #trumphealth.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-10-06T13:00:54Z',
#                         'publishedAt': '2025-10-06T13:00:54Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/UbwaJQLdeLk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'BIZARRE: Trump brags about his personal '
#                                  'health in speech intended to celebrate the '
#                                  'Navy #shorts'}},
#            {'etag': 'ghiNpdMe4BeDC4QMO9vmP1yqfIw',
#             'id': {'kind': 'youtube#video', 'videoId': 'XI0vDlgCZbU'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCUykE2XJkEd2IfMh3NQFKVg',
#                         'channelTitle': 'Hatching For Health',
#                         'description': 'After a life-changing injury, the path '
#                                        'to healing can be long—but it can also '
#                                        'reveal incredible strength. In this '
#                                        'inspiring episode ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-08T20:00:34Z',
#                         'publishedAt': '2025-11-08T20:00:34Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/XI0vDlgCZbU/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'The Road to Recovery: Overcoming Personal '
#                                  'Injury | Hatching for Health Episode 10'}},
#            {'etag': 'EVbegMvGakCwigJrmGIZa2CgZDM',
#             'id': {'kind': 'youtube#video', 'videoId': '76I8nJolcGE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCmFSofrafYUmIrJglhzhjTA',
#                         'channelTitle': 'Ольга Шишова, гл.врач ц Целиус '
#                                         'Москва, профессор',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-06T07:25:40Z',
#                         'publishedAt': '2026-02-06T07:25:40Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/76I8nJolcGE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/76I8nJolcGE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/76I8nJolcGE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Когда Здоровье Разрушает Личную Жизнь'}},
#            {'etag': 'Ln1BrM-T9A-rUemg_1hP_6za2bs',
#             'id': {'kind': 'youtube#video', 'videoId': 'Mlww9rzn1XM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZEOvoFUl6pkx7rts8KKkhw',
#                         'channelTitle': 'Boxing Social',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-02T14:46:50Z',
#                         'publishedAt': '2025-12-02T14:46:50Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/Mlww9rzn1XM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Chris Eubank Jr provides an update on his '
#                                  'personal health battles on social media. 🙏'}},
#            {'etag': '_ghsE3yKr6HpT9rYAmSsBl0hj0o',
#             'id': {'kind': 'youtube#video', 'videoId': '6Xt5WIeQ7aw'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC_vt34wimdCzdkrzVejwX9g',
#                         'channelTitle': 'Geo News',
#                         'description': 'bangladeshelection2026 '
#                                        '#shahzebkhanzada #geonews '
#                                        '#bangladeshelection #sheikhhasina '
#                                        '#narendramodi #bjp #congress ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-12T20:48:48Z',
#                         'publishedAt': '2026-02-12T20:48:48Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/6Xt5WIeQ7aw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/6Xt5WIeQ7aw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/6Xt5WIeQ7aw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Imran Khan&#39;s Health Concerns: No Access '
#                                  'to Personal Doctor? Shahzeb Khanzada – Geo '
#                                  'News'}},
#            {'etag': 'mCYq_HBrqeWCURzbSn3GT5u6j8Y',
#             'id': {'kind': 'youtube#video', 'videoId': 'xHSqr7jAciM'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCBa5G_ESCn8Yd4vw5U-gIcg',
#                         'channelTitle': 'Stanford Online',
#                         'description': "Learn more about Stanford's Healthcare "
#                                        'AI programs: '
#                                        'https://stanford.io/3ETLFCx Check out '
#                                        'the AI in Healthcare series playlist: '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-25T21:43:07Z',
#                         'publishedAt': '2025-11-25T21:43:07Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/xHSqr7jAciM/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AI in Healthcare Series: AI as Your Personal '
#                                  'Health Partner'}},
#            {'etag': 'uF1dx17Gkea68Vr_kxBN4i6J3B8',
#             'id': {'kind': 'youtube#video', 'videoId': 'w5cts1BYI3o'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC8CxefpmMRp2F82bAWAMuhg',
#                         'channelTitle': 'MaxTalksTech',
#                         'description': 'Free personal health companion. Ask '
#                                        'any health question, review your labs, '
#                                        'optimize your health protocol, review '
#                                        'your insurance ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-21T15:12:51Z',
#                         'publishedAt': '2026-02-21T15:12:51Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/w5cts1BYI3o/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Free personal health companion. Ask any '
#                                  'health question, review your labs, optimize '
#                                  'your health'}},
#            {'etag': 'qQD_KUlKwYS3UdmnndL37svGb_Q',
#             'id': {'kind': 'youtube#video', 'videoId': 'oKzwh4sB3P8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCTiQM-IsGr9WggtXVJk1EKg',
#                         'channelTitle': 'Ayuda Health',
#                         'description': 'Experience a smarter way to manage '
#                                        'your #health with Ayuda Health — your '
#                                        'AI-powered personal health assistant. '
#                                        'Whether ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-04T18:49:41Z',
#                         'publishedAt': '2025-11-04T18:49:41Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/oKzwh4sB3P8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'AI-Powered Personal Health Support | Ayuda '
#                                  'Health'}},
#            {'etag': 'tjEYa5uSoN-_-dYv0WFjf8N9Be4',
#             'id': {'kind': 'youtube#video', 'videoId': 'bf7ga8cOHOw'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCF5KYharGnPAHlvmvAGsATw',
#                         'channelTitle': 'Mr Phoenix ASMR',
#                         'description': 'Today we are doing a classic cranial '
#                                        "nerve examination, we'll take a look "
#                                        'at your eyes, ears, nose and mouth. '
#                                        'The video contains ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-22T21:00:36Z',
#                         'publishedAt': '2026-02-22T21:00:36Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/bf7ga8cOHOw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/bf7ga8cOHOw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/bf7ga8cOHOw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'ASMR A Detailed Cranial Nerve Examination | '
#                                  'Soft Spoken Personal Attention Medical RP'}},
#            {'etag': 'lsjmQXzkPqS-fy7stL28JD8uBcQ',
#             'id': {'kind': 'youtube#video', 'videoId': 'qsS-JSigyKc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC8YCj17jhoHENoLekpSlA2g',
#                         'channelTitle': 'Rasoi ki Pathshala',
#                         'description': 'दर्द नहीं… चुपचाप असर! शरीर के इन 10 '
#                                        'अंगों से सावधान Disclaimer : This '
#                                        'video is for ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-25T08:30:26Z',
#                         'publishedAt': '2026-02-25T08:30:26Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/qsS-JSigyKc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/qsS-JSigyKc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/qsS-JSigyKc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'दर्द नहीं चुपचाप असर! शरीर के इन 10 अंगों से '
#                                  'सावधान #healthtips #health #body #shorts'}},
#            {'etag': 'fr1S--ADQhg5XRx1VD_1Z8ad5FM',
#             'id': {'kind': 'youtube#video', 'videoId': '2-8b2uZBfe8'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCHQ4lSaKRap5HyrpitrTOhQ',
#                         'channelTitle': 'Thais Gibson - Personal Development '
#                                         'School',
#                         'description': 'Embrace Breakthroughs With The “Heal '
#                                        'From a Breakup” Course. Free for Life '
#                                        'With a 7-Day Trial.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-24T16:00:06Z',
#                         'publishedAt': '2026-01-24T16:00:06Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/2-8b2uZBfe8/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/2-8b2uZBfe8/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/2-8b2uZBfe8/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'A Personal Health Share That Might Help '
#                                  'You'}},
#            {'etag': 'gGI8u0bAuR48nBAJSEn9pxHHiCA',
#             'id': {'kind': 'youtube#video', 'videoId': 'qoq0nalk-Mk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCD-JAqmpkvkOP4f2kbfuD0w',
#                         'channelTitle': 'frugalrahul',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-07T19:09:29Z',
#                         'publishedAt': '2026-01-07T19:09:29Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/qoq0nalk-Mk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/qoq0nalk-Mk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/qoq0nalk-Mk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Financial Health Check 👍❌ Did you pass the '
#                                  'personal finance wellness test?'}},
#            {'etag': 'N_ozYikRR12bjPiVCGjKy4CQItM',
#             'id': {'kind': 'youtube#video', 'videoId': 'YmYnEG8tZTo'},
#             'kind': 'youtube#searchResult',
# ...
#            {'etag': 'G6VhEC7OZgYlD8AeFujFKX7SIAE',
#             'id': {'kind': 'youtube#video', 'videoId': 'GCvOLSrir1M'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCkCy3xcN257Hb_VWWU5C5vA',
#                         'channelTitle': 'Gals On The Go Podcast',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-12-28T14:35:22Z',
#                         'publishedAt': '2025-12-28T14:35:22Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/GCvOLSrir1M/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/GCvOLSrir1M/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/GCvOLSrir1M/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'chat 🤝all of our personal health questions '
#                                  '#chatgpt #unhinged #2025'}},
#            {'etag': 'RaEHd90oI9tMiChcBdIADsQgv9k',
#             'id': {'kind': 'youtube#video', 'videoId': 'GC3ESoBDZHQ'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCtaBCY6T18XgWUblGhjzEog',
#                         'channelTitle': 'ShortyShorts',
#                         'description': 'From celebrity makeovers to personal '
#                                        'health quirks, a comedian unpacks '
#                                        'societal shifts and celebrates the '
#                                        'power of mental ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T19:00:29Z',
#                         'publishedAt': '2026-02-23T19:00:29Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/GC3ESoBDZHQ/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/GC3ESoBDZHQ/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/GC3ESoBDZHQ/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Katt Williams - Kidney Stones, Ozempic &amp; '
#                                  'The Truth About Health! #shorts'}},
#            {'etag': 'vETuGExgYL9Brw-G9prmdrs8K40',
#             'id': {'kind': 'youtube#video', 'videoId': 'ewyzmGZjvfk'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCUzybWGzmOOS6w0KokFTRnQ',
#                         'channelTitle': 'The Dr. Phil Podcast',
#                         'description': 'Dr. Phil revisits his conversation '
#                                        'with Dr. Chloe. Cancel culture thrives '
#                                        "when you stay silent. Dr. Chloe's new "
#                                        'book gives you the ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-11-04T05:42:38Z',
#                         'publishedAt': '2025-11-04T05:42:38Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/ewyzmGZjvfk/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/ewyzmGZjvfk/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/ewyzmGZjvfk/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Masterclass In Mental Health: Personal '
#                                  'Power, And Social Survival EP611 | The Dr. '
#                                  'Phil Podcast'}},
#            {'etag': '3HHtKM1w1rmmpapMR_5XrQGhw-o',
#             'id': {'kind': 'youtube#video', 'videoId': 'WbjWPFEsZXc'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCLJux67EoAJ1qNe1JKErO8g',
#                         'channelTitle': 'Star Health Insurance',
#                         'description': 'In this video we will talk about '
#                                        'health insurance for accidents where '
#                                        'we will cover everything related to '
#                                        'permanent disability cover ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2025-09-01T09:44:38Z',
#                         'publishedAt': '2025-09-01T09:44:38Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/WbjWPFEsZXc/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/WbjWPFEsZXc/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/WbjWPFEsZXc/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Personal Accident Health Insurance Plan | '
#                                  'Permanent Disability Cover by Star Health '
#                                  'Insurance'}},
#            {'etag': '26zw3gCrzyLBV-bekUGUPSPdqHA',
#             'id': {'kind': 'youtube#video', 'videoId': 'AmXZdeBrukE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC14S_Iw7uaEze614b46EEAg',
#                         'channelTitle': 'Mark Devlin',
#                         'description': 'Natural health guru and nutritionist '
#                                        'Clive de Carle is back. As before, he '
#                                        'presents some revelations which fly in '
#                                        'the face of what ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-15T09:16:53Z',
#                         'publishedAt': '2026-01-15T09:16:53Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/AmXZdeBrukE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/AmXZdeBrukE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/AmXZdeBrukE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'GOOD VIBRATIONS PODCAST, VOL  268   CLIVE DE '
#                                  'CARLE  - PERSONAL HEALTH SOVEREIGNTY (RELOAD '
#                                  'FROM 2025)'}},
#            {'etag': 'gYItlrfCEnRIEKzYHemzIgxXcnc',
#             'id': {'kind': 'youtube#video', 'videoId': 'eu2282oLo80'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCNVM7XaCBUuucfBPG7OBWjA',
#                         'channelTitle': 'BioFacts 3D',
#                         'description': 'What Happens Inside Your Body After '
#                                        'Eating an Egg | 3D Medical Animation '
#                                        'What actually happens inside your body '
#                                        'after eating ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-23T05:00:44Z',
#                         'publishedAt': '2026-02-23T05:00:44Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/eu2282oLo80/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/eu2282oLo80/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/eu2282oLo80/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'What Happens Inside Your Body After Eating '
#                                  'an Egg | 3D Medical Animation'}},
#            {'etag': 'EkBIxN3qmykq1IdcKB4vok2C-JI',
#             'id': {'kind': 'youtube#video', 'videoId': 'g0Oea9JIo1M'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCo32ygBKkkJXPFi-Uw6kOzw',
#                         'channelTitle': 'Niall Kiddle',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-07T10:44:07Z',
#                         'publishedAt': '2026-02-07T10:44:07Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/g0Oea9JIo1M/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/g0Oea9JIo1M/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/g0Oea9JIo1M/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': '7 signs your personal hygiene routine is '
#                                  'damaging your health'}},
#            {'etag': '9vnxfAr23bVv7BwkceFVzawp5cw',
#             'id': {'kind': 'youtube#video', 'videoId': 'kj1Z0H_lx44'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCVbsFo8aCgvIRIO9RYwsQMA',
#                         'channelTitle': 'Zee 24 Taas',
#                         'description': 'amravati #government #Zee24Taas '
#                                        '#MarathiNewsTodayLive '
#                                        '#MarathiNewsTodayLive '
#                                        '#maharashtrapolitics Amravati Health '
#                                        '...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-02-22T08:11:39Z',
#                         'publishedAt': '2026-02-22T08:11:39Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/kj1Z0H_lx44/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/kj1Z0H_lx44/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/kj1Z0H_lx44/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Amravati Health Officer Using Official '
#                                  'Vehical For Personal Use | सरकारी वाहन '
#                                  'घरगुती कामासाठी'}},
#            {'etag': '7P_jdoFVtgjc7TWu63tMWENYRUE',
#             'id': {'kind': 'youtube#video', 'videoId': 'hZHHY6C_SsE'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UC534I3EAakWm0KfqGlJXJ1A',
#                         'channelTitle': 'CityNews021',
#                         'description': 'Important Message of the personal '
#                                        'doctor of Imran Khan regarding the '
#                                        'current health condition of former '
#                                        'prime minister Dr Asim ...',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-30T17:11:38Z',
#                         'publishedAt': '2026-01-30T17:11:38Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/hZHHY6C_SsE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/hZHHY6C_SsE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/hZHHY6C_SsE/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Imran Khan Health Condition - Important '
#                                  'Message of Personal Doctor (Dr Asim '
#                                  'Yousuf)'}},
#            {'etag': '5TkU_Cz3BsiHau_2QMmNjV1ylGI',
#             'id': {'kind': 'youtube#video', 'videoId': 'sr8nQ8zA9hw'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCxXAbekxbLzmAJGeHS2-XuA',
#                         'channelTitle': 'THE GLAM',
#                         'description': '',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2026-01-08T19:11:15Z',
#                         'publishedAt': '2026-01-08T19:11:15Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/sr8nQ8zA9hw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/sr8nQ8zA9hw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/sr8nQ8zA9hw/mqdefault.jpg',
#                                                   'width': 320}},
#                         'title': 'Dr. Dre Faces Major Health Scare During '
#                                  'Personal Turmoil #shorts #viral #drdre'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1000000},
#  'regionCode': 'US'}

# %%
# For each search result:
for item in response["items"]:
    # Print the video's title & channel title
    print(item["snippet"]["title"])
    print(item["snippet"]["channelTitle"])
    print("------------")
# Out:
# Health Expert Manthena Satyanarayana Raju Reveals Shocking 35-Year Personal Hygiene Habits
# CineeVerge
# ------------
# Complete Women’s Health Solutions | Ft. Dr. Jamil Mehravi With Osama Tayyab
# Osama Tayyab Podcast
# ------------
# Cillian Murphy on how he personally and his advice for those struggling with their mental health
# The Hook
# ------------
# Եթե չեք ուզում քաղցկեղով հիվանդանալ #facts #healthadvice #armeniatv #healthtips #help #viral
# Elen’s life USA
# ------------
# How To Choose Best Health Insurance Plan In India 2026 | SAGAR SINHA
# Sagar Sinha
# ------------
# A personal update about my health.
# River
# ------------
# Personal + Channel Update: Twin sister, health and what&#39;s ahead!
# Diana Kokku
# ------------
# Personal Hygiene Glow-Up for Women|Body Care, Menstrual Health &amp; Freshness Tips #shorts #tamilshorts
# Aval Siru Megam
# ------------
# Event Recap：AI-Driven Preventive Healthcare Launch Event - Your Personal Health Butler Is Now Online
# LIVE4WELL
# ------------
# The Art of Ageing Well. Samantha | Mona Sharma
# Samantha
# ------------
# Doctor&#39;s Appointment - My Personal Health - Future Plans - Big Trip Coming
# The Carpetbagger
# ------------
# Will Downing on Staying True to His Sound, Navigating Health &amp; Personal Loss, and Resilience
# The Donnie Simpson Show
# ------------
# Pioneering &amp; Personal | Advanced Care | Sutter Health
# Sutter Health
# ------------
# Shiori Shares a Personal Health Update【Hololive EN】
# Novelitedits
# ------------
# Harrison Smith Feeds the Local Media Jackals, Talks Personal Health Issue
# Purple FTW! Podcast
# ------------
# The doctor forwent personal accolades to focus on healing the patient before him.
# Gözde Dgn
# ------------
# Top 10 Health Benefits of Cardamom | এলাচ খাওয়ার উপকারিতা | Weight Loss &amp; Heart Health
# Dr. Tasnim Health Care
# ------------
# Foods as Medicine | Everyday Foods That Support Your Heart, Brain, and Eyes
# Healthy Empire
# ------------
# BIZARRE: Trump brags about his personal health in speech intended to celebrate the Navy #shorts
# David Pakman Show
# ------------
# The Road to Recovery: Overcoming Personal Injury | Hatching for Health Episode 10
# Hatching For Health
# ------------
# Когда Здоровье Разрушает Личную Жизнь
# Ольга Шишова, гл.врач ц Целиус Москва, профессор
# ------------
# Chris Eubank Jr provides an update on his personal health battles on social media. 🙏
# Boxing Social
# ------------
# Imran Khan&#39;s Health Concerns: No Access to Personal Doctor? Shahzeb Khanzada – Geo News
# Geo News
# ------------
# AI in Healthcare Series: AI as Your Personal Health Partner
# Stanford Online
# ------------
# Free personal health companion. Ask any health question, review your labs, optimize your health
# MaxTalksTech
# ------------
# AI-Powered Personal Health Support | Ayuda Health
# Ayuda Health
# ------------
# ASMR A Detailed Cranial Nerve Examination | Soft Spoken Personal Attention Medical RP
# Mr Phoenix ASMR
# ------------
# दर्द नहीं चुपचाप असर! शरीर के इन 10 अंगों से सावधान #healthtips #health #body #shorts
# Rasoi ki Pathshala
# ------------
# A Personal Health Share That Might Help You
# Thais Gibson - Personal Development School
# ------------
# Financial Health Check 👍❌ Did you pass the personal finance wellness test?
# frugalrahul
# ------------
# ABC Juice = Health BoostBlended perfectly with Agaro Regal 3 Personal Mixer Grinder
# Sara Daily recipes
# ------------
# Individual VS Family Floater Health Insurance  | WHICH ONE IS BETTER ? | Gurleen Kaur Tikku
# Gurleen Kaur Tikku
# ------------
# Having a personal health insurance policy means you own your own health cover.
# OneInsure
# ------------
# Foods as Medicine | What These Everyday Foods Secretly Repair Inside Your Body
# Healthy Empire
# ------------
# Future Doctor… But I’m Fighting Something Serious | Health Update
# The Bong MBBS Boy
# ------------
# The Heart-breaking Reality of Trying to Get Pregnant
# The Clinic
# ------------
# SAD NEWS: Prince Edward Forced to Pull Out Due to Health! 🚨 #royal #news #breakingnews
# The Crown Exposed
# ------------
# Personal Preferences are not Mental Health Boundaries #Relationships #MentalHealth #Shorts
# Aperture
# ------------
# AI-Powered Wellness: Your Personal Health Coach
# CGTN Podcasts
# ------------
# Corporate Health Cover vs Personal Policy | Biggest Insurance Mistake Employees Make
# Telugu Assets
# ------------
# chat 🤝all of our personal health questions #chatgpt #unhinged #2025
# Gals On The Go Podcast
# ------------
# Katt Williams - Kidney Stones, Ozempic &amp; The Truth About Health! #shorts
# ShortyShorts
# ------------
# Masterclass In Mental Health: Personal Power, And Social Survival EP611 | The Dr. Phil Podcast
# The Dr. Phil Podcast
# ------------
# Personal Accident Health Insurance Plan | Permanent Disability Cover by Star Health Insurance
# Star Health Insurance
# ------------
# GOOD VIBRATIONS PODCAST, VOL  268   CLIVE DE CARLE  - PERSONAL HEALTH SOVEREIGNTY (RELOAD FROM 2025)
# Mark Devlin
# ------------
# What Happens Inside Your Body After Eating an Egg | 3D Medical Animation
# BioFacts 3D
# ------------
# 7 signs your personal hygiene routine is damaging your health
# Niall Kiddle
# ------------
# Amravati Health Officer Using Official Vehical For Personal Use | सरकारी वाहन घरगुती कामासाठी
# Zee 24 Taas
# ------------
# Imran Khan Health Condition - Important Message of Personal Doctor (Dr Asim Yousuf)
# CityNews021
# ------------
# Dr. Dre Faces Major Health Scare During Personal Turmoil #shorts #viral #drdre
# THE GLAM
# ------------

# %%
# Verify # of items matches input response
if len(response["items"]) == 50:
    print("Number of results matches input search criterion!")
else:
    print(f"MISMATCH! Received only {len(response["items"])} video results.")
# Out:
# Number of results matches input search criterion!

# %% [markdown]
# ## Stage 2: Transcript Extraction
#
# Video IDs are extracted from the search response, passed to the transcript API, and saved per-video to `data/transcripts/raw/{video_id}.json` and `data/transcripts/cleaned/{video_id}.txt`.

# %% [markdown]
# ### Fetch Video IDs from Search Response

# %%
query_video_ids = []

# For each search result
for item in response["items"]:
    query_video_ids.append(item['id']['videoId'])

# Print for validation
print(f"TOTAL # of Video IDs: {len(query_video_ids)}")

print("Sample First 5 Video IDs:\n-----------")
for i in range(0, 5):
    print(query_video_ids[i])
# Out:
# TOTAL # of Video IDs: 50
# Sample First 5 Video IDs:
# -----------
# MHv-qEhCstA
# -rscIfp-HW4
# FpDWFoHOzi0
# OwauZygLH_Q
# Aklx_zrToRs

# %% [markdown]
# ### Filtering for High-Impact Videos
# For each video in queried set of IDs, check the video atttributes to filter only high-impact videos.
# - We set the criterion here so we need to justify that.
# - Return a subset of original queried IDs which fulfil the criterion.

# %%
def chunk_video_ids(lst, n):
    """Breaks down any input series of video_ids into smaller subset of lists. Going to be useful to handle API request limits. """
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

    
def fetch_video_metadata(youtube, video_ids):
    """Helper function to get hydrated set of video metrics beyond search"""
    all_items = []

    for job in chunk_video_ids(video_ids, 50):
        resp = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=",".join(job),
            maxResults = 50
        ).execute()

        all_items.extend(resp.get("items", []))
    
    return all_items

# %%
video_mds = fetch_video_metadata(youtube, query_video_ids)
print(len(video_mds), video_mds[0].keys())
# Out:
# 50 dict_keys(['kind', 'etag', 'id', 'snippet', 'contentDetails', 'statistics'])

# %%
print("ContentDetails:")
pprint(video_mds[0]['contentDetails'])

print("\nStatistics")
pprint(video_mds[0]['statistics'])

print("\nSnippet")
pprint(video_mds[0]['snippet'])
# Out:
# ContentDetails:
# {'caption': 'false',
#  'contentRating': {},
#  'definition': 'hd',
#  'dimension': '2d',
#  'duration': 'PT6S',
#  'licensedContent': True,
#  'projection': 'rectangular'}
#
# Statistics
# {'commentCount': '249',
#  'favoriteCount': '0',
#  'likeCount': '7638',
#  'viewCount': '2865957'}
#
# Snippet
# {'categoryId': '27',
#  'channelId': 'UCBQJKez34g7jkSoH3_noUaQ',
#  'channelTitle': 'CineeVerge',
#  'defaultAudioLanguage': 'zxx',
#  'defaultLanguage': 'en',
#  'description': 'Manthena Satyanarayana Raju | Naturopathy Lifestyle | No Soap '
#                 'For 35 Years | Tongue Cleaning Secret | Personal Hygiene '
#                 'Habits | Dr Manthena Interview | Viral Health Tips | Natural '
#                 'Living | Socks Washing Habit | Health Mantra | Arogyalayam '
#                 'Vijayawada | Soap Free Bathing | Natural Skin Care | '
#                 'Traditional Health Practices | Manthena Satyanarayana Raju '
#                 'Statement | Telugu Health Expert | Lifestyle Secrets | Body '
#                 'Odor Prevention | Natural Healing | Chemical Free Life | '
#                 'Healthy Habits | Viral Social Media News | Naturopathy Diet | '
#                 'Telugu Cinema News | Celebrity Health Tips | Wellness Journey '
#                 '| No Chemicals | Self Discipline | Unique Lifestyle | Health '
#                 'Motivation | Cineeverge\n'
#                 '\n'
#                 '\n'
#                 '#cineeverge #ManthenaSatyanarayanaRaju #Naturopathy '
#                 '#HealthTips #NaturalLiving #HygieneSecrets #NoSoap '
#                 '#HealthyLifestyle #TeluguHealth #Wellness #TrendingNews '
#                 '#ViralInterview #HealthMantra #Arogyalayam '
#                 '#TraditionalHealing #NaturalBeauty #ChemicalFree #LifeSecrets '
#                 '#Motivation #TeluguNews #HealthyHabits #BodyCare '
#                 '#Sustainability #NaturopathicMedicine #ViralUpdate '
#                 '#HealthAwareness #SimpleLiving #WellnessCoach #IndianCulture '
#                 '#HealthIsWealth #LifeLessons #UniqueHabits #FitnessMotivation '
#                 '#MindfulLiving',
#  'liveBroadcastContent': 'none',
#  'localized': {'description': 'Manthena Satyanarayana Raju | Naturopathy '
#                               'Lifestyle | No Soap For 35 Years | Tongue '
#                               'Cleaning Secret | Personal Hygiene Habits | Dr '
#                               'Manthena Interview | Viral Health Tips | '
#                               'Natural Living | Socks Washing Habit | Health '
#                               'Mantra | Arogyalayam Vijayawada | Soap Free '
#                               'Bathing | Natural Skin Care | Traditional '
#                               'Health Practices | Manthena Satyanarayana Raju '
#                               'Statement | Telugu Health Expert | Lifestyle '
#                               'Secrets | Body Odor Prevention | Natural '
#                               'Healing | Chemical Free Life | Healthy Habits | '
#                               'Viral Social Media News | Naturopathy Diet | '
#                               'Telugu Cinema News | Celebrity Health Tips | '
#                               'Wellness Journey | No Chemicals | Self '
#                               'Discipline | Unique Lifestyle | Health '
#                               'Motivation | Cineeverge\n'
#                               '\n'
#                               '\n'
#                               '#cineeverge #ManthenaSatyanarayanaRaju '
#                               '#Naturopathy #HealthTips #NaturalLiving '
#                               '#HygieneSecrets #NoSoap #HealthyLifestyle '
#                               '#TeluguHealth #Wellness #TrendingNews '
#                               '#ViralInterview #HealthMantra #Arogyalayam '
#                               '#TraditionalHealing #NaturalBeauty '
#                               '#ChemicalFree #LifeSecrets #Motivation '
#                               '#TeluguNews #HealthyHabits #BodyCare '
#                               '#Sustainability #NaturopathicMedicine '
#                               '#ViralUpdate #HealthAwareness #SimpleLiving '
#                               '#WellnessCoach #IndianCulture #HealthIsWealth '
#                               '#LifeLessons #UniqueHabits #FitnessMotivation '
#                               '#MindfulLiving',
#                'title': 'Health Expert Manthena Satyanarayana Raju Reveals '
#                         'Shocking 35-Year Personal Hygiene Habits'},
#  'publishedAt': '2026-01-13T02:30:05Z',
#  'thumbnails': {'default': {'height': 90,
#                             'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/default.jpg',
#                             'width': 120},
#                 'high': {'height': 360,
#                          'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/hqdefault.jpg',
#                          'width': 480},
#                 'maxres': {'height': 720,
#                            'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/maxresdefault.jpg',
#                            'width': 1280},
#                 'medium': {'height': 180,
#                            'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/mqdefault.jpg',
#                            'width': 320},
#                 'standard': {'height': 480,
#                              'url': 'https://i.ytimg.com/vi/MHv-qEhCstA/sddefault.jpg',
#                              'width': 640}},
#  'title': 'Health Expert Manthena Satyanarayana Raju Reveals Shocking 35-Year '
#           'Personal Hygiene Habits'}

# %%
print(f"Snippet Keys: {video_mds[0]['snippet'].keys()}")
# Out:
# Snippet Keys: dict_keys(['publishedAt', 'channelId', 'title', 'description', 'thumbnails', 'channelTitle', 'categoryId', 'liveBroadcastContent', 'defaultLanguage', 'localized', 'defaultAudioLanguage'])

# %% [markdown]
# - Factors from Videos.list() to add to video DB schema:
#     - Snippet: `categoryId`
#     - Statistics:  `commentCount, likeCount, viewCount`
#     - ContentDetails: `duration`

# %%
### Compute Engagement Metrics for Filtration of Records
from datetime import datetime, timezone
import math

def compute_impact_features(vid_metadata):
    """Provided a video dictionary from videos().list() --> we want to return a dict with derived impact features."""

    stats = vid_metadata.get("statistics", {})
    snippet = vid_metadata.get("snippet", {})

    # Raw Engagement Data
    view_count = int(stats.get("viewCount", 0))
    comment_count = int(stats.get("commentCount", 0))
    like_count = int(stats.get("likeCount", 0))
    published_at = datetime.fromisoformat(
        snippet["publishedAt"].replace("Z", "+00:00")
    )
    days_since = max(
        (datetime.now(timezone.utc) - published_at).days,
        1  # avoid divide-by-zero
    )

    # Derived metrics from API provided data
    views_per_day = view_count / days_since
    comments_per_1kviews = ((comment_count / view_count) * 1000) if view_count > 0 else 0
    likes_per_1kviews = ((like_count / view_count) * 1000) if view_count > 0 else 0

    # Metric weightage (impact score calculation)
    reach = math.log10(view_count + 1)
    momentum = math.log10(views_per_day + 1)

    # Normalized engagement scores
    engagement = math.log10(comments_per_1kviews + 1) + math.log10(likes_per_1kviews + 1)
    impact_score = 0.45 * reach + 0.35 * momentum + 0.20 * engagement

    
    return {
        "video_id": vid_metadata["id"],
        "view_count": view_count,
        "views_per_day": views_per_day,
        "comments_per_1kviews": comments_per_1kviews,
        "likes_per_1kviews": likes_per_1kviews,
        "impact_score": impact_score,
    }

# %%
# Percentile-Based Filtering --> accomodates for cases when number of videos per call vary, so the cutoff is malleable with respect to video ids pulled.
def filter_ws_by_percentile(scored_videos, percentile=0.9):
    """
    Keeps videos above the given percentile of impact_score.
    Example: percentile=0.9 keeps top 10%.
    """

    if not scored_videos:
        return []

    # Sort by impact_score descending
    scored_videos.sort(
        key=lambda x: x["impact_score"],
        reverse=True
    )

    cutoff_index = int(len(scored_videos) * percentile)

    # Prevent empty return
    cutoff_index = min(cutoff_index, len(scored_videos) - 1)
    threshold_score = scored_videos[cutoff_index]["impact_score"]

    filtered = [
        v for v in scored_videos
        if v["impact_score"] >= threshold_score
    ]

    return filtered

# %%
MIN_COMMENTS_PER_1K = 2.5      # 0.25%
MIN_LIKES_PER_1K = 25         # 2.5%
MIN_VIEWS = 1000             

# Calculated each video's eval metrics
video_impact_metrics = [
    compute_impact_features(v)
    for v in video_mds
]

fails_like = sum(v["likes_per_1kviews"] < 25 for v in video_impact_metrics)
fails_comment = sum(v["comments_per_1kviews"] < 2.5 for v in video_impact_metrics)
fails_both = sum((v["likes_per_1kviews"] < 25) and (v["comments_per_1kviews"] < 2.5) for v in video_impact_metrics)

print("total:", len(video_impact_metrics))
print("fails_like:", fails_like)
print("fails_comment:", fails_comment)
print("fails_both:", fails_both)

# Skip low-engagement / low-reach videos
eligible_videos = [
    v for v in video_impact_metrics
    if (
        v["view_count"] >= MIN_VIEWS and
        v["comments_per_1kviews"] >= MIN_COMMENTS_PER_1K and
        v["likes_per_1kviews"] >= MIN_LIKES_PER_1K
    )
]

# Filter for top 10%
high_impact_videos = filter_ws_by_percentile(
    eligible_videos,
    percentile=0.25
)

# Return final set of eligible video IDs
filtered_video_ids = [
    v["video_id"] for v in high_impact_videos
]
# Out:
# total: 50
# fails_like: 26
# fails_comment: 36
# fails_both: 25
# 4

# %% [markdown]
# ### Extract and Clean Transcripts
# - Use external YT Transcripts API for 2-stage data ingestion
# - Defined a helper function to collapse JSON structure and remove noise; resulting cleaned transcript is stored as a .txt object.

# %%
# clean_transcript defined in imports cell above
def clean_transcript(transcript_data: Union[List[Dict], str]) -> str:
    """
    Clean a YouTube transcript by removing noise and formatting artifacts into .txt blob.
    """
    if isinstance(transcript_data, str):
        text = transcript_data
    else:
        text = " ".join([item.text for item in transcript_data])
    text = re.sub(r'^>\s*', '', text, flags=re.MULTILINE)
    text = re.sub(r'(?:^|\s)(?:[A-Z][a-z]*(?:\s+[A-Z][a-z]*)?)\s*:\s*', ' ', text)
    text = re.sub(r'\[[^\]]*\]', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\([^)]*\)', '', text)
    for pattern in [r'\b(?:um|uh|ugh|hmm)\b', r'\byou\s+know\b', r'\blike\b(?=\s+(?:he|she|they|it|the|a|i))']:
        text = re.sub(pattern, '', text, flags=re.IGNORECASE)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.!?])\s+(?=[a-z])', lambda m: m.group(1) + ' ', text)
    text = text.strip()
    if text and text[0].islower():
        text = text[0].upper() + text[1:]
    return text

# %%
ytt_api = YouTubeTranscriptApi()
formatter = JSONFormatter()

Path("data/transcripts/raw").mkdir(parents=True, exist_ok=True)
Path("data/transcripts/cleaned").mkdir(parents=True, exist_ok=True)

print(f"Number of candidate video IDs to evaluate: {len(filtered_video_ids)}")

for video_id in filtered_video_ids:
    try:
        raw_transcript = ytt_api.fetch(video_id)
        json_formatted = formatter.format_transcript(raw_transcript, indent=2)
        Path(f"data/transcripts/raw/{video_id}.json").write_text(json_formatted, encoding="utf-8")
        cleaned = clean_transcript(raw_transcript)
        Path(f"data/transcripts/cleaned/{video_id}.txt").write_text(cleaned, encoding="utf-8")
    except Exception:
        print(f"No transcript available for Video ID: {video_id}")
# Out:
# Number of candidate video IDs to evaluate: 4
# No transcript available for Video ID: KYLg0cvPZ5Y
# No transcript available for Video ID: pP0cCa7CbQo
# No transcript available for Video ID: w5cts1BYI3o
# No transcript available for Video ID: Kg_NGJeEUyY

# %%
# Validate data that is being stored in the directories for now; make sure we have the same # of entries in both subidrectories (raw - cleaned)
raw_count = len([p for p in Path("data/transcripts/raw").iterdir() if p.is_file()])
cleaned_count = len([p for p in Path("data/transcripts/cleaned").iterdir() if p.is_file()])

if raw_count == cleaned_count:
    print(f"Verification successful: {raw_count} files in both directories.")
else:
    print(f"Mismatch: {raw_count} raw files, {cleaned_count} cleaned files.")
# Out:
# Verification successful: 4 files in both directories.

# %% [markdown]
# ## Next Steps
#
# See [README.md](README.md) for setup instructions and the full project workflow. The pipeline is headed in the following direction:
#
# 1. **Search enhancements** — Add views/impressions filtering via `videos.list` for more targeted discovery
# 2. **Batch processing** — Extend transcript extraction to all video IDs (currently processes the first video only)
# 3. **Supabase migration** — Move ingested data from local `data/` storage to Supabase (as noted in Data Storage above)
# 4. **Downstream use** — Cleaned transcripts are ready for LLM-based insight generation and analysis
#
# Run this notebook after configuring `YOUTUBE_DATA_API_KEY` in `.env` (see README).
